# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/prasertcbs/454_2566/main/data/Top%2015%20Automakers%20in%20the%20World.csv')
df
# Out:
#         Automaker  Year  Sold Autos Status  World Rank
# 0          Toyota  2022     9566961   ↑ 1%           1
# 1          Toyota  2021     9562483   ↑ 1%           1
# 2          Toyota  2020     9528753  ↓ 11%           1
# 3              VW  2022     8263104   ↓ 7%           2
# 4              VW  2021     8882346   ↓ 5%           2
# 5              VW  2020     9305427  ↓ 15%           2
# 6     Hyundai Kia  2022     6848198   ↑ 3%           3
# 7     Hyundai Kia  2021     6668037   ↑ 5%           3
# 8     Hyundai Kia  2020     6353514  ↓ 12%           4
# 9      Stellantis  2022     6002900   ↓ 2%           4
# 10     Stellantis  2021     6142200   ↓ 1%           5
# 11     Stellantis  2020     6205996  ↓ 23%           5
# 12             GM  2022     5941737   ↓ 6%           5
# 13             GM  2021     6294385   ↓ 8%           4
# 14             GM  2020     6833592  ↓ 11%           3
# 15           Ford  2022     4235737   ↑ 7%           6
# 16           Ford  2021     3942755   ↓ 7%           8
# 17           Ford  2020     4231549  ↓ 22%           7
# 18          Honda  2022     4074372   ↓ 9%           7
# 19          Honda  2021     4456728   ↓ 6%           6
# 20          Honda  2020     4790438  ↓ 10%           6
# 21         Nissan  2022     3225478  ↓ 21%           8
# 22         Nissan  2021     4064999   ↑ 1%           7
# 23         Nissan  2020     4029174  ↓ 22%           8
# 24            BMW  2022     2399636   ↓ 5%           9
# 25            BMW  2021     2521596   ↑ 8%          10
# 26            BMW  2020     2324778   ↓ 8%          10
# 27        Changan  2022     2347163   ↑ 1%          10
# 28        Changan  2021     2314547  ↑ 15%          11
# 29        Changan  2020     2003663  ↑ 14%          12
# 30        Renault  2022     2051174  ↓ 24%          11
# 31        Renault  2021     2689454   ↓ 5%           9
# 32        Renault  2020     2949871  ↓ 21%           9
# 33       Mercedes  2022     2043900   ↓ 2%          12
# 34       Mercedes  2021     2093476   ↓ 3%          12
# 35       Mercedes  2020     2164275   ↓ 8%          11
# 36  Maruti Suzuki  2022     1940067  ↑ 17%          13
# 37  Maruti Suzuki  2021     1652653  ↑ 13%          13
# 38  Maruti Suzuki  2020     1457861   ↓ 7%          13
# 39          Geely  2022     1432988   ↑ 8%          14
# 40          Geely  2021     1328029   ↑ 1%          14
# 41          Geely  2020     1320471   ↓ 1%          14
# 42          Tesla  2022     1369611  ↑ 47%          15
# 43          Tesla  2021      930422  ↑ 83%          18
# 44          Tesla  2020      509737  ↑ 40%          27

# %%
#ถ้าลด ให้แก้เป็น -.11 ถ้าเพิ่ม เขียนเป็น 0.03
df["Status"].str.replace('%', '').str.replace('↑ ','').str.replace('↓ ','-').astype(float)/100
# Out:
# 0     0.01
# 1     0.01
# 2    -0.11
# 3    -0.07
# 4    -0.05
# 5    -0.15
# 6     0.03
# 7     0.05
# 8    -0.12
# 9    -0.02
# 10   -0.01
# 11   -0.23
# 12   -0.06
# 13   -0.08
# 14   -0.11
# 15    0.07
# 16   -0.07
# 17   -0.22
# 18   -0.09
# 19   -0.06
# 20   -0.10
# 21   -0.21
# 22    0.01
# 23   -0.22
# 24   -0.05
# 25    0.08
# 26   -0.08
# 27    0.01
# 28    0.15
# 29    0.14
# 30   -0.24
# 31   -0.05
# 32   -0.21
# 33   -0.02
# 34   -0.03
# 35   -0.08
# 36    0.17
# 37    0.13
# 38   -0.07
# 39    0.08
# 40    0.01
# 41   -0.01
# 42    0.47
# 43    0.83
# 44    0.40
# Name: Status, dtype: float64

# %%
df["Status"] = df["Status"].str.replace('%', '').str.replace('↑ ','').str.replace('↓ ','-').astype(float)/100
df
# Out:
#         Automaker  Year  Sold Autos  Status  World Rank
# 0          Toyota  2022     9566961    0.01           1
# 1          Toyota  2021     9562483    0.01           1
# 2          Toyota  2020     9528753   -0.11           1
# 3              VW  2022     8263104   -0.07           2
# 4              VW  2021     8882346   -0.05           2
# 5              VW  2020     9305427   -0.15           2
# 6     Hyundai Kia  2022     6848198    0.03           3
# 7     Hyundai Kia  2021     6668037    0.05           3
# 8     Hyundai Kia  2020     6353514   -0.12           4
# 9      Stellantis  2022     6002900   -0.02           4
# 10     Stellantis  2021     6142200   -0.01           5
# 11     Stellantis  2020     6205996   -0.23           5
# 12             GM  2022     5941737   -0.06           5
# 13             GM  2021     6294385   -0.08           4
# 14             GM  2020     6833592   -0.11           3
# 15           Ford  2022     4235737    0.07           6
# 16           Ford  2021     3942755   -0.07           8
# 17           Ford  2020     4231549   -0.22           7
# 18          Honda  2022     4074372   -0.09           7
# 19          Honda  2021     4456728   -0.06           6
# 20          Honda  2020     4790438   -0.10           6
# 21         Nissan  2022     3225478   -0.21           8
# 22         Nissan  2021     4064999    0.01           7
# 23         Nissan  2020     4029174   -0.22           8
# 24            BMW  2022     2399636   -0.05           9
# 25            BMW  2021     2521596    0.08          10
# 26            BMW  2020     2324778   -0.08          10
# 27        Changan  2022     2347163    0.01          10
# 28        Changan  2021     2314547    0.15          11
# 29        Changan  2020     2003663    0.14          12
# 30        Renault  2022     2051174   -0.24          11
# 31        Renault  2021     2689454   -0.05           9
# 32        Renault  2020     2949871   -0.21           9
# 33       Mercedes  2022     2043900   -0.02          12
# 34       Mercedes  2021     2093476   -0.03          12
# 35       Mercedes  2020     2164275   -0.08          11
# 36  Maruti Suzuki  2022     1940067    0.17          13
# 37  Maruti Suzuki  2021     1652653    0.13          13
# 38  Maruti Suzuki  2020     1457861   -0.07          13
# 39          Geely  2022     1432988    0.08          14
# 40          Geely  2021     1328029    0.01          14
# 41          Geely  2020     1320471   -0.01          14
# 42          Tesla  2022     1369611    0.47          15
# 43          Tesla  2021      930422    0.83          18
# 44          Tesla  2020      509737    0.40          27

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Automaker   45 non-null     object
#  1   Year        45 non-null     int64
#  2   Sold Autos  45 non-null     int64
#  3   Status      45 non-null     float64
#  4   World Rank  45 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.9+ KB

# %%
df.columns
# Out:
# Index(['Automaker', 'Year', 'Sold Autos', 'Status', 'World Rank'], dtype='object')

# %%
print(f'pandas version = {pd.__version__}')
print(f'seaborn version = {sns.__version__}')
# Out:
# pandas version = 2.2.0
# seaborn version = 0.13.1

# %%
df['Year']=df['Year'].astype(str)
df
# Out:
#         Automaker  Year  Sold Autos  Status  World Rank
# 0          Toyota  2022     9566961    0.01           1
# 1          Toyota  2021     9562483    0.01           1
# 2          Toyota  2020     9528753   -0.11           1
# 3              VW  2022     8263104   -0.07           2
# 4              VW  2021     8882346   -0.05           2
# 5              VW  2020     9305427   -0.15           2
# 6     Hyundai Kia  2022     6848198    0.03           3
# 7     Hyundai Kia  2021     6668037    0.05           3
# 8     Hyundai Kia  2020     6353514   -0.12           4
# 9      Stellantis  2022     6002900   -0.02           4
# 10     Stellantis  2021     6142200   -0.01           5
# 11     Stellantis  2020     6205996   -0.23           5
# 12             GM  2022     5941737   -0.06           5
# 13             GM  2021     6294385   -0.08           4
# 14             GM  2020     6833592   -0.11           3
# 15           Ford  2022     4235737    0.07           6
# 16           Ford  2021     3942755   -0.07           8
# 17           Ford  2020     4231549   -0.22           7
# 18          Honda  2022     4074372   -0.09           7
# 19          Honda  2021     4456728   -0.06           6
# 20          Honda  2020     4790438   -0.10           6
# 21         Nissan  2022     3225478   -0.21           8
# 22         Nissan  2021     4064999    0.01           7
# 23         Nissan  2020     4029174   -0.22           8
# 24            BMW  2022     2399636   -0.05           9
# 25            BMW  2021     2521596    0.08          10
# 26            BMW  2020     2324778   -0.08          10
# 27        Changan  2022     2347163    0.01          10
# 28        Changan  2021     2314547    0.15          11
# 29        Changan  2020     2003663    0.14          12
# 30        Renault  2022     2051174   -0.24          11
# 31        Renault  2021     2689454   -0.05           9
# 32        Renault  2020     2949871   -0.21           9
# 33       Mercedes  2022     2043900   -0.02          12
# 34       Mercedes  2021     2093476   -0.03          12
# 35       Mercedes  2020     2164275   -0.08          11
# 36  Maruti Suzuki  2022     1940067    0.17          13
# 37  Maruti Suzuki  2021     1652653    0.13          13
# 38  Maruti Suzuki  2020     1457861   -0.07          13
# 39          Geely  2022     1432988    0.08          14
# 40          Geely  2021     1328029    0.01          14
# 41          Geely  2020     1320471   -0.01          14
# 42          Tesla  2022     1369611    0.47          15
# 43          Tesla  2021      930422    0.83          18
# 44          Tesla  2020      509737    0.40          27

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Automaker   45 non-null     object
#  1   Year        45 non-null     object
#  2   Sold Autos  45 non-null     int64
#  3   Status      45 non-null     float64
#  4   World Rank  45 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 1.9+ KB

# %%
sns.barplot(data=df, x="Sold Autos", y="Automaker");

# %%
#Tesla ควรมี 3 แท่ง เพราะมี 3 ปี 
import matplotlib.ticker as ticker
g=sns.barplot(data=df, x="Sold Autos", y="Automaker", hue="Year", palette="Blues_r"); #แยกตามปี, Blues_r คือไล่สีเข้มจากปีเก่าสุด ถ้าไม่มี_r คือจากปีล่าสุด
g.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f"{x/1e6:,.1f})m"))
plt.tight_layout()
plt.savefig('a2.png') #save graph เป็นรูป แต่จะได้รูปแหว่งข้างซ้าย ,วิธีแก้คือบรรทัดข้างบน
#plt.savefig('a2.svg') #ความละเอียดชัดสุด ติดตั้ง extension svg
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
#plot 3 รูป 3 ปี
g = sns.catplot( #catplot -> กราฟแต่ละแกนเป็นตัวอักษร กับ ตัวเลข ส่วน replot 2 แกนต้องเป็นตัวเลขทั้งคู่ (อุณหภูมิ ไรงี้ก็ได้)
    df,
    kind="bar",
    y="Automaker",
    x="Sold Autos",
    col="Year", #column
    color=".7", #ยิ่งค่าน้อยยิ่งดำ
    col_wrap=3, #พอครบ3รูปให้ขึ้นแถวใหม่
    height=3.5,
    aspect=1.6, #ความกว้าง
    sharex=True, #share ข้อมูลแกน x ทุกรูปจะมีสเกลแกน x เท่ากัน
)
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
#ใช้ catplot แต่ก็ยังมีรูปเดียว
g = sns.catplot(
    data=df[df['Year']=='2022'], #filter ตัว df ได้ จะได้มีแค่ปีเดียว
    # data=df,
    kind="bar",
    y="Automaker",
    x="Sold Autos",
    hue='Year',
    # color=".7",
    palette='Blues_r',
    height=5,
    aspect=1.6,
    sharex=True,
    errorbar=None 
)
ax=g.axes[0][0]
ax.set_ylabel('')
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f"{x/1e6:.0f}m"))
ax.set_title('top 15 automakers')
plt.tight_layout()
plt.savefig('temp_chart.svg')
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
from ipywidgets import widgets, interact

# %%
#ใช้ interactive มาช่วย
palette_list = [
    "#cccccc", #สีเดียว ต้องมี # ตามด้วยรหัสสี
    "Blues_r",
    "Blues",
    "Oranges_r",
    "Oranges",
    "Set1",
    "Set2",
    "Set3",
    "Pastel1",
    "Pastel2",
    "Blues",
    "Greens",
    "Oranges",
    "deep",
    "muted",
    "pastel",
    "bright",
    "dark",
    "colorblind", 
]

savefig_checkbox = widgets.Checkbox(
    value=False,  # Set the initial value
    description='save chart1.png',  # Set the label next to the checkbox
    disabled=False  # Set to True to disable the checkbox
)

#@interact -> decorator
@interact(palette=palette_list, is_savefig=savefig_checkbox)
def plot_chart(palette=palette_list, is_savefig=False):
    g = sns.catplot(
        df,
        kind="bar",
        y="Automaker",
        x="Sold Autos",
        col="Year",
        color=".7",
        col_wrap=3,
        height=3.5,
        aspect=1.6,
        sharex=True,
        palette=[palette] if palette[0]=='#' else palette #
    )

    # Define a formatter function to convert tick labels to millions
    def millions_formatter(x, pos):
        return f"{x/1e6:.0f}M"


    # Get the axes object from the catplot
    for ax in g.axes:
        # Set the formatter to the y-axis ticks
        ax.xaxis.set_major_formatter(ticker.FuncFormatter(millions_formatter))
        ax.set_ylabel("")
        ax.set_title(re.sub(".* = ", "", ax.get_title()))

    if is_savefig:
        g.savefig('chart1.png')
# Out:
# interactive(children=(Dropdown(description='palette', options=('#cccccc', 'Blues_r', 'Blues', 'Oranges_r', 'Or…

# %%
# ใช้ slider ตรง sold
palette_list = [
    "#cccccc",
    "Blues_r",
    "Blues",
    "Greens_r",
    "Greens",
    "Oranges_r",
    "Oranges",
    "Set1",
    "Set2",
    "Set3",
    "Pastel1",
    "Pastel2",
    "deep",
    "muted",
    "pastel",
    "bright",
    "dark",
    "colorblind",
]

sales_range = widgets.IntRangeSlider( # ** มีแบบ int กับ float 
    value=[0, df["Sold Autos"].max()], #กำหนดช่วงของตัวเลข
    min=0, #กำหนดค่าเริ่มต้น
    max=df["Sold Autos"].max(), #กำหนดค่าเริ่มต้น
    step=1e6, #step ละ ล้าน
    description="Sold:", #ชื่อของslider
    disabled=False, 
    continuous_update=False,
    orientation="horizontal",
    readout=True,
    readout_format="d",
)


@interact(sales=sales_range, palette=palette_list)
def plot_chart(sales, palette=palette_list):
    g = sns.catplot(
        df[(df["Sold Autos"] >= sales[0]) & (df["Sold Autos"] <= sales[1])],
        kind="bar",
        y="Automaker",
        x="Sold Autos",
        col="Year",
        color=".7",
        col_wrap=3,
        height=3.5,
        aspect=1.6,
        sharex=True,
        palette=[palette] if palette[0] == "#" else palette,
    )
    # Get the axes object from the catplot
    axes = g.axes
    # g

    # Define a formatter function to convert tick labels to millions
    def millions_formatter(x, pos):
        return f"{x/1e6:.0f}M"

    # Set the formatter to the y-axis ticks
    for ax in axes:
        # ax.xaxis.set_major_formatter(ticker.FuncFormatter(millions_formatter))
        ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f"{x/1e6:.0f}M"))
# Out:
# interactive(children=(IntRangeSlider(value=(0, 9566961), continuous_update=False, description='Sold:', max=956…
