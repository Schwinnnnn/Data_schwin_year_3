# %% [markdown]
# #### สมาชิกกลุ่ม โนบิเต๋อเพื่อนโนบิตะ <span style="color: var(--vscode-foreground);">
# #### 1.นิธิพล โพธิสาร 6441124926<span style="color: var(--vscode-foreground);">
# #### 2.ธีรัช ถวัลประสิทธิ์ 6441108926<span style="color: var(--vscode-foreground);">
# #### 3.นาย ชวิน แย้มเสมอ 6441050026<span style="color: var(--vscode-foreground);">
# #### 4.นาย ณัชพล ฤทธิ์แรงกล้า 6441067826<span style="color: var(--vscode-foreground);">
# #### 5.นาย ฉัตรธรรม ฉัตรอมรรัตน์ 6441036326<span style="color: var(--vscode-foreground);">
# #### 6.นาย ณัฏฐพัชร์ ถาวรวิทยาคม 6441069026<span style="color: var(--vscode-foreground);">

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # <span style="color:lightBLue;"><strong>Low Sugar Soft drink trend in Thailand&nbsp;</strong></span>

# %% [markdown]
# #### วิเคราะห์ข้อมูลของ Soft drink Market size ของประเทศไทยเทียบกับประเทศอื่น ๆ ทั่วโลก โดยที่ปัจจุบันการบริโภคน้ำอัดลมแบบ Low sugarมีอัตราที่เพิ่มขึ้นอย่างมาก เนื่องจาก trend ในการดื่ม Low sugar Soft drink และ trend การรักสุขภาพมากขึ้น <span style="color: var(--vscode-foreground);">
#
#
#
# <span style="color:white"><img src="https://github.com/KNithipon/Projectbi1/raw/main/Packshot%20info%20-%20Coke%20Zero%20Sugar%20180ml%20-%20Cover%20x%201_2.jpg.webp" height="300"><img src="https://github.com/KNithipon/Projectbi1/raw/main/TH-Pepsi-No-Sugar-325ml-Pack-6-Right-view-postprod-01.jpg.webp" height="300">
# <img src="https://github.com/KNithipon/Projectbi1/raw/main/1200130-2_5-coca-cola-diet-coke-soft-drink.jpg.webp" height="300"></span>ม

# %% [markdown]
# ## <span style="color:lightBLue;"><strong>1. ข้อมูลปริมาณที่ขายในแต่ละประเทศทั่วโลก&nbsp;</strong></span>

# %%
df1=pd.read_csv('average_revenue_per_household.csv' )

df1
# Out:
#     YEAR  CODE_SOCIO_ECON                                     SOCIO_ECONOMIC  \
# 0   2554                0                  รวมสถานะทางเศรษฐสังคมของครัวเรือน
# 1   2554                1  ผู้ถือครองทำการเกษตร การปลูกพืช การเลี้ยงสัตว์...
# 2   2554                2  ผู้ถือครองทำการเกษตร การปลูกพืช การเลี้ยงสัตว์...
# 3   2554                3  ผู้ทำการประมง ป่าไม้ ล่าสัตว์ หาของป่า และบริก...
# 4   2554                4           ผู้ดำเนินธุรกิจของตนเองที่ไม่ใช่การเกษตร
# ..   ...              ...                                                ...
# 61  2564                6                                         คนงานเกษตร
# 62  2564                7                                        คนงานทั่วไป
# 63  2564                8               เสมียนพนักงาน พนักงานขายและให้บริการ
# 64  2564                9                       ผู้ปฏิบัติงานในกระบวนการผลิต
# 65  2564               10                  ผู้ไม่ได้ปฏิบัติงานในเชิงเศรษฐกิจ
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression

color = ["lightgray", "lightgray", "lightgray", "red", "red", "red"]

# Assuming df1 is your DataFrame
df1['SOCIO_ECONOMIC'].replace({'รวมสถานะทางเศรษฐสังคมของครัวเรือน': 'total'}, inplace=True)
df_filtered = df1[df1['SOCIO_ECONOMIC'] == 'total']

# Group by 'SOCIO_ECONOMIC' and 'year', then calculate the mean income
mean_income_by_socioeconomic = df_filtered.groupby(['SOCIO_ECONOMIC', 'YEAR'])['FROM_WORK'].mean().reset_index()

# Plotting the bar chart with specified colors
plt.figure(figsize=(10, 6))
for socio_economic_group, group_data in mean_income_by_socioeconomic.groupby('SOCIO_ECONOMIC'):
    plt.bar(group_data['YEAR'], group_data['FROM_WORK'], label=socio_economic_group, color=color)

# Adding line graph
plt.plot(mean_income_by_socioeconomic['YEAR'], mean_income_by_socioeconomic['FROM_WORK'], color='blue', marker='o', label='Line Graph')

plt.xlabel('Year')
plt.ylabel('Mean Money Income')
plt.title('Mean Money Income by Socio-Economic Group Over the Years')
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display

# Assuming df1 is your DataFrame
# Assuming color is predefined

# Create a function to update the plot based on the selected socio-economic group
def update_plot(selected_socio_economic):
    df_filtered = df1[df1['SOCIO_ECONOMIC'] == selected_socio_economic]

    # Group by 'SOCIO_ECONOMIC' and 'year', then calculate the mean income
    mean_income_by_socioeconomic = df_filtered.groupby(['SOCIO_ECONOMIC', 'YEAR'])['FROM_WORK'].mean().reset_index()

    # Plotting the bar chart with specified colors
    plt.figure(figsize=(10, 6))
    for socio_economic_group, group_data in mean_income_by_socioeconomic.groupby('SOCIO_ECONOMIC'):
        plt.bar(group_data['YEAR'], group_data['FROM_WORK'], label=socio_economic_group, color=color)

    # Adding line graph
    plt.plot(mean_income_by_socioeconomic['YEAR'], mean_income_by_socioeconomic['FROM_WORK'], color='blue', marker='o', label='Line Graph')

    plt.xlabel('Year')
    plt.ylabel('Mean Money Income')
    plt.title('Mean Money Income by Socio-Economic Group Over the Years')
    plt.legend()
    plt.show()

# Get unique values of 'SOCIO_ECONOMIC' column
socio_economic_values = df1['SOCIO_ECONOMIC'].unique().tolist()

# Create a dropdown widget
dropdown_socio_economic = widgets.Dropdown(options=socio_economic_values, description='Socio-Economic:')

# Display the dropdown widget
display(dropdown_socio_economic)

# Create an event handler to update the plot when the dropdown value changes
def on_dropdown_change(change):
    update_plot(change.new)

# Attach the event handler to the dropdown widget
dropdown_socio_economic.observe(on_dropdown_change, names='value')

# Initialize the plot with the first value in the dropdown list
update_plot(socio_economic_values[0])
# Out:
# Dropdown(description='Socio-Economic:', options=('รวมสถานะทางเศรษฐสังคมของครัวเรือน', 'ผู้ถือครองทำการเกษตร กา…
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 3619 (\N{THAI CHARACTER RO RUA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 3623 (\N{THAI CHARACTER WO WAEN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 3617 (\N{THAI CHARACTER MO MA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 3626 (\N{THAI CHARACTER SO SUA}) missing from current font.
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display

# Assuming df1 is your DataFrame
# Assuming color is predefined

# Create a function to update the plot based on the selected socio-economic group and column
def update_plot(selected_socio_economic, selected_column):
    plt.clf()  # Clear the previous plot

    df_filtered = df1[df1['SOCIO_ECONOMIC'] == selected_socio_economic]

    # Group by 'SOCIO_ECONOMIC' and 'year', then calculate the mean income for the selected column
    mean_income_by_socioeconomic = df_filtered.groupby(['SOCIO_ECONOMIC', 'YEAR'])[selected_column].mean().reset_index()

    # Plotting the bar chart with specified colors
    for socio_economic_group, group_data in mean_income_by_socioeconomic.groupby('SOCIO_ECONOMIC'):
        plt.bar(group_data['YEAR'], group_data[selected_column], label=socio_economic_group, color=color)

    # Adding line graph
    plt.plot(mean_income_by_socioeconomic['YEAR'], mean_income_by_socioeconomic[selected_column], color='blue', marker='o', label='Line Graph')

    plt.xlabel('Year')
    plt.ylabel(f'Mean {selected_column}')
    plt.title(f'Mean {selected_column} by Socio-Economic Group Over the Years')
    plt.legend()
    plt.show()

# Get unique values of 'SOCIO_ECONOMIC' column
socio_economic_values = df1['SOCIO_ECONOMIC'].unique().tolist()

# Get unique values of the columns you want to include in the dropdown
column_values = ['MONTHLY_INCOME', 'CURRENT_INCOME', 'MONEY_INCOME', 'FROM_WORK', 'CURRENT_TRANSFER', 'PROPERTY_INCOME', 'NONMONEY_INCOME', 'NONCUR_M_INCOME']

# Create dropdown widgets for socio-economic group and column selection
dropdown_socio_economic = widgets.Dropdown(options=socio_economic_values, description='Socio-Economic:')
dropdown_column = widgets.Dropdown(options=column_values, description='Select Column:')

# Display the dropdown widgets
display(dropdown_socio_economic)
display(dropdown_column)

# Create event handlers to update the plot when the dropdown values change
def on_dropdown_change(change):
    update_plot(dropdown_socio_economic.value, dropdown_column.value)

# Attach the event handlers to the dropdown widgets
dropdown_socio_economic.observe(on_dropdown_change, names='value')
dropdown_column.observe(on_dropdown_change, names='value')

# Initialize the plot with the first values in the dropdown lists
update_plot(socio_economic_values[0], column_values[0])
# Out:
# Dropdown(description='Socio-Economic:', options=('รวมสถานะทางเศรษฐสังคมของครัวเรือน', 'ผู้ถือครองทำการเกษตร กา…
# Dropdown(description='Select Column:', options=('MONTHLY_INCOME', 'CURRENT_INCOME', 'MONEY_INCOME', 'FROM_WORK…
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 3619 (\N{THAI CHARACTER RO RUA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 3623 (\N{THAI CHARACTER WO WAEN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 3617 (\N{THAI CHARACTER MO MA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
df2=pd.read_csv('cost_per_household.csv')

df2
# Out:
#       YEAR           REGION          AREA  \
# 0     2554  ทั่วราชอาณาจักร           รวม
# 1     2554  ทั่วราชอาณาจักร           รวม
# 2     2554  ทั่วราชอาณาจักร           รวม
# 3     2554  ทั่วราชอาณาจักร           รวม
# 4     2554  ทั่วราชอาณาจักร           รวม
# ...    ...              ...           ...
# 1507  2564           ภาคใต้  นอกเขตเทศบาล
# 1508  2564           ภาคใต้  นอกเขตเทศบาล
# 1509  2564           ภาคใต้  นอกเขตเทศบาล
# 1510  2564           ภาคใต้  นอกเขตเทศบาล
# 1511  2564           ภาคใต้  นอกเขตเทศบาล
#
#                                   TYPE_EXPENSE  VALUE UNIT  \
# 0                   ค่าใช้จ่ายทั้งสิ้นต่อเดือน  17403  บาท
# 1               ค่าใช้จ่ายเพื่อการอุปโภคบริโภค  15328  บาท
# 2        อาหาร และเครื่องดื่ม (ไม่มีแอลกอฮอล์)   5660  บาท
# 3                    เครื่องดื่มที่มีแอลกอฮอล์     95  บาท
# 4                ยาสูบ หมาก ยานัตถุ์ และอื่นๆ      85  บาท
# ...                                        ...    ...  ...
# ...

# %%
data=pd.read_excel('https://github.com/Schwinnnnn/Data_schwin_year_3/raw/main/Bi/Passport_Stats_28-01-2024_1410_GMT.xls' )

data
# Out:
#    Geography                                         Category  Year  \
# 0   Thailand         Obese Population (BMI 30kg/sq m or More)  2015
# 1   Thailand    Male Obese population (BMI 30kg/sq m or More)  2015
# 2   Thailand  Female Obese population (BMI 30kg/sq m or More)  2015
# 3   Thailand         Obese Population (BMI 30kg/sq m or More)  2016
# 4   Thailand    Male Obese population (BMI 30kg/sq m or More)  2016
# 5   Thailand  Female Obese population (BMI 30kg/sq m or More)  2016
# 6   Thailand         Obese Population (BMI 30kg/sq m or More)  2017
# 7   Thailand    Male Obese population (BMI 30kg/sq m or More)  2017
# 8   Thailand  Female Obese population (BMI 30kg/sq m or More)  2017
# 9   Thailand         Obese Population (BMI 30kg/sq m or More)  2018
# 10  Thailand    Male Obese population (BMI 30kg/sq m or More)  2018
# 11  Thailand  Female Obese population (BMI 30kg/sq m or More)  2018
# 12  Thailand         Obese Population (BMI 30kg/sq m or More)  2019
# ...

# %%
year_columns = data.columns[4:]
cumulative_growth = data[year_columns].div(data[year_columns].iloc[:, 0], axis=0) * 100
cumulative_growth['Geography'] = data['Geography'] 
melted_data = cumulative_growth.melt(id_vars='Geography', var_name='Year', value_name='Cumulative Growth')
colors = {country: 'red' if country == 'Thailand' else 'lightgrey' for country in melted_data['Geography'].unique()}
sns_plot = sns.lineplot(data=melted_data, x='Year', y='Cumulative Growth', hue='Geography', palette=colors)
# Out:
# /Users/nithipon/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/nithipon/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### <span style="color:white;"><strong>รัฐบาลจัดเก็บภาษีความหวานเพิ่มขึ้นในปี 2017&nbsp;</strong></span>
# #### การเก็บภาษีเพื่อสุขภาพกับการแก้ปัญหาโรคไม่ติดต่อเรื้อรัง เช่น โรคอ้วน ของคนไทย <span style="color: white(--vscode-foreground);">
#
# <img src="https://i.ibb.co/cCsLVT3/CCS-5-2563-1.png" height="300">
#
# #### รัฐบาลบรรลุวัตถุประสงค์หรือไม่ ?

# %% [markdown]
# ## <span style="color:lightBLue;"><strong>2. ข้อมูลYear on Year(%)ที่ขายในแต่ละประเทศทั่วโลก&nbsp;</strong></span>

# %%
df1=pd.read_excel('https://github.com/KNithipon/Projectbi1/raw/main/Yoy.xlsx')
df1
# Out:
#     Geography                  Category         Data Type  Year  \
# 0    Malaysia  Reduced Sugar Carbonates  Off-trade Volume  2015
# 1      Taiwan  Reduced Sugar Carbonates  Off-trade Volume  2015
# 2    Thailand  Reduced Sugar Carbonates  Off-trade Volume  2015
# 3   Australia  Reduced Sugar Carbonates  Off-trade Volume  2015
# 4   Argentina  Reduced Sugar Carbonates  Off-trade Volume  2015
# ..        ...                       ...               ...   ...
# 75     Canada  Reduced Sugar Carbonates  Off-trade Volume  2022
# 76        USA  Reduced Sugar Carbonates  Off-trade Volume  2022
# 77    Belgium  Reduced Sugar Carbonates  Off-trade Volume  2022
# 78     France  Reduced Sugar Carbonates  Off-trade Volume  2022
# 79      Spain  Reduced Sugar Carbonates  Off-trade Volume  2022
#
#               Unit   YoY
# 0   million litres   9.6
# 1   million litres  -1.2
# 2   million litres   4.9
# 3   million litres  -1.2
# 4   million litres   3.0
# ..             ...   ...
# ...

# %%
plt.figure(figsize=(10, 6)) 
colors = {country : 'red' if country == 'Thailand' else 'lightgray' for country in df1['Geography'].unique()}

sns.lineplot(data=df1, x='Year', y='YoY', hue='Geography', palette=colors, )
plt.title('Soft drink low sugar')
plt.show()
# Out:
# /Users/nithipon/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/nithipon/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## <span style="color:lightBLue;"><strong>3. Brand Sharesของแต่ละบริษัทในประเทศไทย ในปี2017&nbsp;</strong></span>

# %%
df2=pd.read_excel('https://github.com/KNithipon/Projectbi1/raw/main/Passport_Stats_28-01-2024_1626_GMT.xls',skiprows=5)

df2
# Out:
#   Geography                  Category  \
# 0  Thailand  Reduced Sugar Carbonates
# 1  Thailand  Reduced Sugar Carbonates
# 2  Thailand  Reduced Sugar Carbonates
# 3  Thailand  Reduced Sugar Carbonates
# 4  Thailand  Reduced Sugar Carbonates
#
#                                  Brand Name Company Name (GBO)      Data Type  \
# 0  Coca-Cola Zero Sugar (Coca-Cola Co, The)  Coca-Cola Co, The  Retail Volume
# 1                       Pepsi (PepsiCo Inc)        PepsiCo Inc  Retail Volume
# 2             Diet Coke (Coca-Cola Co, The)  Coca-Cola Co, The  Retail Volume
# 3                   Est (Thai Beverage PCL)  Thai Beverage PCL  Retail Volume
# 4                                    Others             Others  Retail Volume
#
#    2017
# 0  51.1
# 1  36.2
# 2  11.4
# 3   0.9
# 4   0.4

# %%
data_for_pie = df2.groupby('Brand Name')['2017'].sum()

plt.figure(figsize=(8, 8))
plt.title("Brand market size in 2017")
color = ["red","lightgray","lightblue","gray","purple"]

plt.pie(data_for_pie, labels=data_for_pie.index, autopct='%1.1f%%', startangle=140,colors=color )
plt.axis('equal')  
plt.show()

# %% [markdown]
# ## <span style="color:lightBLue;"><strong>4. ข้อมูลสัดส่วนประชากรที่มีค่า BMI มากกว่า30ในประเทศไทย&nbsp;</strong></span>

# %%
df3=pd.read_excel('https://github.com/KNithipon/Projectbi1/raw/main/Passport_Stats_27-01-2024_1629_GMT-2.xls',skiprows=5)
df3
# Out:
#    Geography                                         Category  \
# 0   Thailand         Obese Population (BMI 30kg/sq m or More)
# 1   Thailand    Male Obese population (BMI 30kg/sq m or More)
# 2   Thailand  Female Obese population (BMI 30kg/sq m or More)
# 3   Thailand         Obese Population (BMI 30kg/sq m or More)
# 4   Thailand    Male Obese population (BMI 30kg/sq m or More)
# ..       ...                                              ...
# 67  Thailand    Male Obese population (BMI 30kg/sq m or More)
# 68  Thailand  Female Obese population (BMI 30kg/sq m or More)
# 69  Thailand         Obese Population (BMI 30kg/sq m or More)
# 70  Thailand    Male Obese population (BMI 30kg/sq m or More)
# 71  Thailand  Female Obese population (BMI 30kg/sq m or More)
#
#                     Data Type                             Unit  Year  Percent
# 0   Socio-economic indicators         % of population aged 18+  2000      3.7
# ...

# %%
plt.figure(figsize=(9,6))
sns.lineplot(data=df3, x='Year', y = 'Percent',hue = 'Category')
plt.title('BMI > 30 (Obesity)')
# Out:
# /Users/nithipon/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/nithipon/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'BMI > 30 (Obesity)')

# %% [markdown]
# # <span style="color:lightblue"><strong><strong>CITATIONS</strong>&nbsp;&nbsp;</strong></span>
# - BBC. (n.d.). ภาษีความหวาน: การเก็บภาษีเพื่อสุขภาพกับความพยายามแก้ปัญหาโรคไม่ติดต่อเรื้อรังของคนไทย. BBC News ไทย. https://www.bbc.com/thai/thailand-49115597
# - Limited, B. P. P. C. (n.d.). Sugary drink tax pushes innovation. Bangkok Post. Retrieved January 29, 2024, from https://www.bangkokpost.com/business/general/1720635
# - ทำไมแบรนด์เครื่องดื่ม ถึงหันมาผลิตสูตร “หวานน้อย” มากขึ้น ? (2022, June 12). www.marketthink.co. https://www.marketthink.co/27112
# - น้ำอัดลมสูตรน้ำตาล 0% ไม่ทำให้อ้วนจริงหรือ? (2023, July 10). www.sanook.com/Health. https://www.sanook.com/health/5653/
# - (2024). Oclc.org. https://www-portal-euromonitor-com.chula.idm.oclc.org/magazine/homemain/
#
# ‌
