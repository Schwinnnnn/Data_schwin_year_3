# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import ipywidgets as widgets
from IPython.display import display

# %%
df1 = pd.read_csv("https://github.com/Schwinnnnn/Data_schwin_year_3/raw/main/Bi/project2/average_revenue_per_household.csv")

# %%
df1['SOCIO_ECONOMIC'].replace({'รวมสถานะทางเศรษฐสังคมของครัวเรือน': 'Household status aggregation'}, inplace=True)
df1['SOCIO_ECONOMIC'].replace({'ผู้ถือครองทำการเกษตร การปลูกพืช การเลี้ยงสัตว์ และการเพาะเลี้ยงสัตวน้ำ ซึ่งที่ดินส่วนใหญ่เป็นของตนเอง': 'The landowner engages in agriculture on their own land'}, inplace=True)
df1['SOCIO_ECONOMIC'].replace({'ผู้ถือครองทำการเกษตร การปลูกพืช การเลี้ยงสัตว์ และการเพาะเลี้ยงสัตวน้ำ ซึ่งที่ดินส่วนใหญ่เช่าผู้อื่น/ที่สาธารณะ/อื่น ๆ': 'The landowner engages in agriculture on land that leased from others'}, inplace=True)
df1['SOCIO_ECONOMIC'].replace({'ผู้ทำการประมง ป่าไม้ ล่าสัตว์ หาของป่า และบริการทางการเกษตร': 'The individual engages in fishing, forestry and agricultural services'}, inplace=True)
df1['SOCIO_ECONOMIC'].replace({'ผู้ดำเนินธุรกิจของตนเองที่ไม่ใช่การเกษตร': 'The self-employed individual unrelated to agriculture'}, inplace=True)
df1['SOCIO_ECONOMIC'].replace({'ผู้ปฏิบัติงานวิชาชีพ นักวิชาการ และนักบริหารที่รับจ้าง': 'The professional worker is employed on a contractual basis'}, inplace=True)
df1['SOCIO_ECONOMIC'].replace({'คนงานเกษตร': 'The agricultural laborer'}, inplace=True)
df1['SOCIO_ECONOMIC'].replace({'คนงานทั่วไป': 'General laborer'}, inplace=True)
df1['SOCIO_ECONOMIC'].replace({'เสมียนพนักงาน พนักงานขายและให้บริการ': 'Sales and service staff'}, inplace=True)
df1['SOCIO_ECONOMIC'].replace({'ผู้ปฏิบัติงานในกระบวนการผลิต': 'Production workers'}, inplace=True)
df1['SOCIO_ECONOMIC'].replace({'ผู้ไม่ได้ปฏิบัติงานในเชิงเศรษฐกิจ': 'Non-economic workforce'}, inplace=True)
df1
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_41656\1588716534.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['SOCIO_ECONOMIC'].replace({'รวมสถานะทางเศรษฐสังคมของครัวเรือน': 'Household status aggregation'}, inplace=True)
#     YEAR  CODE_SOCIO_ECON                                     SOCIO_ECONOMIC  \
# 0   2554                0                       Household status aggregation
# 1   2554                1  The landowner engages in agriculture on their ...
# 2   2554                2  The landowner engages in agriculture on land t...
# 3   2554                3  The individual engages in fishing, forestry an...
# 4   2554                4  The self-employed individual unrelated to agri...
# ..   ...              ...                                                ...
# 61  2564                6                           The agricultural laborer
# 62  2564                7                                    General laborer
# 63  2564                8                            Sales and service staff
# 64  2564                9                                 Production workers
# 65  2564               10                             Non-economic workforce
#
#     MONTHLY_INCOME  CURRENT_INCOME  MONEY_INCOME  FROM_WORK  CURRENT_TRANSFER  \
# 0            23236           22873         19712      16719              2527
# 1            20378           19935         16832      15405              1320
# 2            18238           17830         14967      13467              1476
# 3            12244           12107         10067       9342               695
# 4            30922           30544         27465      26273               864
# ..             ...             ...           ...        ...               ...
# 61           16059           15954         12645      11376              1250
# 62           17302           17197         13767      12451              1292
# 63           26668           26478         22094      20676              1331
# 64           24095           23947         20108      19043              1042
# 65           18202           17448         12657       1897             10203
#
#     PROPERTY_INCOME  NONMONEY_INCOME  NONCUR_M_INCOME UNIT  \
# 0               466             3161              363  บาท
# 1               107             3103              444  บาท
# 2                24             2863              408  บาท
# 3                31             2040              137  บาท
# 4               328             3079              379  บาท
# ..              ...              ...              ...  ...
# 61               18             3309              106  บาท
# 62               24             3431              105  บาท
# 63               86             4385              190  บาท
# 64               23             3838              148  บาท
# 65              557             4791              753  บาท
#
#                    SOURCE
# 0   สำนักงานสถิติแห่งชาติ
# 1   สำนักงานสถิติแห่งชาติ
# 2   สำนักงานสถิติแห่งชาติ
# 3   สำนักงานสถิติแห่งชาติ
# 4   สำนักงานสถิติแห่งชาติ
# ..                    ...
# 61  สำนักงานสถิติแห่งชาติ
# 62  สำนักงานสถิติแห่งชาติ
# 63  สำนักงานสถิติแห่งชาติ
# 64  สำนักงานสถิติแห่งชาติ
# 65  สำนักงานสถิติแห่งชาติ
#
# [66 rows x 13 columns]

# %%
color = ["lightgray", "lightgray", "red", "red", "red", "red"]
# Assuming df1 is your DataFrame
# Assuming color is predefined

# Create a function to update the plot based on the selected socio-economic group and column
def update_plot(selected_socio_economic, selected_column):
    plt.clf()  # Clear the current figure

    df_filtered = df1[df1['SOCIO_ECONOMIC'] == selected_socio_economic]

    # Group by 'SOCIO_ECONOMIC' and 'year', then calculate the mean income for the selected column
    mean_income_by_socioeconomic = df_filtered.groupby(['SOCIO_ECONOMIC', 'YEAR'])[selected_column].mean().reset_index()

    # Plotting the bar chart with specified colors
    for socio_economic_group, group_data in mean_income_by_socioeconomic.groupby('SOCIO_ECONOMIC'):
        plt.bar(group_data['YEAR'], group_data[selected_column], label=socio_economic_group, color=color)

    # Adding line graph
    plt.plot(mean_income_by_socioeconomic['YEAR'], mean_income_by_socioeconomic[selected_column], color='blue', marker='o', label='Line Graph')

    plt.xlabel('Year')
    plt.ylabel(f'Mean {selected_column}')
    plt.title(f'Mean {selected_column} by Socio-Economic Group Over the Years')
    plt.show()

# Get unique values of 'SOCIO_ECONOMIC' column
socio_economic_values = df1['SOCIO_ECONOMIC'].unique().tolist()

# Get unique values of the columns you want to include in the dropdown
column_values = ['MONTHLY_INCOME', 'CURRENT_INCOME', 'MONEY_INCOME', 'FROM_WORK', 'CURRENT_TRANSFER', 'PROPERTY_INCOME', 'NONMONEY_INCOME', 'NONCUR_M_INCOME']

# Create dropdown widgets for socio-economic group and column selection
dropdown_socio_economic = widgets.Dropdown(options=socio_economic_values, description='Socio-Economic:')
dropdown_column = widgets.Dropdown(options=column_values, description='Select Column:')

# Display the dropdown widgets
display(dropdown_socio_economic)
display(dropdown_column)

# Create event handlers to update the plot when the dropdown values change
def on_dropdown_change(change):
    update_plot(dropdown_socio_economic.value, dropdown_column.value)

# Attach the event handlers to the dropdown widgets
dropdown_socio_economic.observe(on_dropdown_change, names='value')
dropdown_column.observe(on_dropdown_change, names='value')

# Initialize the plot with the first values in the dropdown lists
update_plot(socio_economic_values[0], column_values[0])
# Out:
# Dropdown(description='Socio-Economic:', options=('Household status aggregation', 'The landowner engages in agr…
# Dropdown(description='Select Column:', options=('MONTHLY_INCOME', 'CURRENT_INCOME', 'MONEY_INCOME', 'FROM_WORK…

# %%
df2 = pd.read_csv("https://github.com/Schwinnnnn/Data_schwin_year_3/raw/main/Bi/project2/cost_per_household.csv")

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1512 entries, 0 to 1511
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   YEAR          1512 non-null   int64
#  1   REGION        1512 non-null   object
#  2   AREA          1512 non-null   object
#  3   TYPE_EXPENSE  1512 non-null   object
#  4   VALUE         1512 non-null   int64
#  5   UNIT          1512 non-null   object
#  6   SOURCE        1512 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 82.8+ KB

# %%
df2.head()
# Out:
#    YEAR           REGION AREA                           TYPE_EXPENSE  VALUE  \
# 0  2554  ทั่วราชอาณาจักร  รวม             ค่าใช้จ่ายทั้งสิ้นต่อเดือน  17403
# 1  2554  ทั่วราชอาณาจักร  รวม         ค่าใช้จ่ายเพื่อการอุปโภคบริโภค  15328
# 2  2554  ทั่วราชอาณาจักร  รวม  อาหาร และเครื่องดื่ม (ไม่มีแอลกอฮอล์)   5660
# 3  2554  ทั่วราชอาณาจักร  รวม              เครื่องดื่มที่มีแอลกอฮอล์     95
# 4  2554  ทั่วราชอาณาจักร  รวม          ยาสูบ หมาก ยานัตถุ์ และอื่นๆ      85
#
#   UNIT                 SOURCE
# 0  บาท  สำนักงานสถิติแห่งชาติ
# 1  บาท  สำนักงานสถิติแห่งชาติ
# 2  บาท  สำนักงานสถิติแห่งชาติ
# 3  บาท  สำนักงานสถิติแห่งชาติ
# 4  บาท  สำนักงานสถิติแห่งชาติ

# %%
df2["TYPE_EXPENSE"].unique()
# Out:
# array(['ค่าใช้จ่ายทั้งสิ้นต่อเดือน', 'ค่าใช้จ่ายเพื่อการอุปโภคบริโภค',
#        'อาหาร และเครื่องดื่ม (ไม่มีแอลกอฮอล์)',
#        'เครื่องดื่มที่มีแอลกอฮอล์', 'ยาสูบ หมาก ยานัตถุ์ และอื่นๆ\xa0',
#        'ที่อยู่อาศัย เครื่องแต่งบ้าน และเครื่องใช้ต่าง ๆ',
#        'เครื่องนุ่งห่มและรองเท้า', 'ค่าใช้จ่ายส่วนบุคคล',
#        'เวชภัณฑ์และค่าตรวจรักษาพยาบาล', 'การเดินทางและการสื่อสาร',
#        'การศึกษา', 'การบันเทิง การอ่านและกิจกรรมทางศาสนา',
#        'การจัดงานพิธีในโอกาสพิเศษ',
#        'ค่าใช้จ่ายที่ไม่เกี่ยวกับการอุปโภคบริโภค'], dtype=object)

# %%
df2['TYPE_EXPENSE'].replace({'ค่าใช้จ่ายเพื่อการอุปโภคบริโภค': 'Consumption expenses'}, inplace=True)
df2['TYPE_EXPENSE'].replace({'ที่อยู่อาศัย เครื่องแต่งบ้าน และเครื่องใช้ต่าง ๆ': 'Housing, home decorations and appliances'}, inplace=True)
df2['TYPE_EXPENSE'].replace({'อาหาร และเครื่องดื่ม (ไม่มีแอลกอฮอล์)': 'Food and drinks (no alcohol)'}, inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_41656\1236674138.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2['TYPE_EXPENSE'].replace({'ค่าใช้จ่ายเพื่อการอุปโภคบริโภค': 'Consumption expenses'}, inplace=True)

# %%
expense_list = ["Consumption expenses", "Housing, home decorations and appliances", "Food and drinks (no alcohol)"]

# %%
df2_filtered = df2[(df2["TYPE_EXPENSE"] == expense_list[0]) | (df2["TYPE_EXPENSE"] == expense_list[1]) | (df2["TYPE_EXPENSE"] == expense_list[2])]

# %%
df2_filtered
# Out:
#       YEAR           REGION          AREA  \
# 1     2554  ทั่วราชอาณาจักร           รวม
# 2     2554  ทั่วราชอาณาจักร           รวม
# 5     2554  ทั่วราชอาณาจักร           รวม
# 15    2554  ทั่วราชอาณาจักร   ในเขตเทศบาล
# 16    2554  ทั่วราชอาณาจักร   ในเขตเทศบาล
# ...    ...              ...           ...
# 1486  2564           ภาคใต้   ในเขตเทศบาล
# 1489  2564           ภาคใต้   ในเขตเทศบาล
# 1499  2564           ภาคใต้  นอกเขตเทศบาล
# 1500  2564           ภาคใต้  นอกเขตเทศบาล
# 1503  2564           ภาคใต้  นอกเขตเทศบาล
#
#                                   TYPE_EXPENSE  VALUE UNIT  \
# 1                         Consumption expenses  15328  บาท
# 2                 Food and drinks (no alcohol)   5660  บาท
# 5     Housing, home decorations and appliances   3553  บาท
# 15                        Consumption expenses  19340  บาท
# 16                Food and drinks (no alcohol)   6117  บาท
# ...                                        ...    ...  ...
# 1486              Food and drinks (no alcohol)   7689  บาท
# 1489  Housing, home decorations and appliances   4891  บาท
# 1499                      Consumption expenses  16834  บาท
# 1500              Food and drinks (no alcohol)   6991  บาท
# 1503  Housing, home decorations and appliances   3544  บาท
#
#                      SOURCE
# 1     สำนักงานสถิติแห่งชาติ
# 2     สำนักงานสถิติแห่งชาติ
# 5     สำนักงานสถิติแห่งชาติ
# 15    สำนักงานสถิติแห่งชาติ
# 16    สำนักงานสถิติแห่งชาติ
# ...                     ...
# 1486  สำนักงานสถิติแห่งชาติ
# 1489  สำนักงานสถิติแห่งชาติ
# 1499  สำนักงานสถิติแห่งชาติ
# 1500  สำนักงานสถิติแห่งชาติ
# 1503  สำนักงานสถิติแห่งชาติ
#
# [324 rows x 7 columns]

# %%
df2_filtered
# Out:
#       YEAR           REGION          AREA  \
# 1     2554  ทั่วราชอาณาจักร           รวม
# 2     2554  ทั่วราชอาณาจักร           รวม
# 5     2554  ทั่วราชอาณาจักร           รวม
# 15    2554  ทั่วราชอาณาจักร   ในเขตเทศบาล
# 16    2554  ทั่วราชอาณาจักร   ในเขตเทศบาล
# ...    ...              ...           ...
# 1486  2564           ภาคใต้   ในเขตเทศบาล
# 1489  2564           ภาคใต้   ในเขตเทศบาล
# 1499  2564           ภาคใต้  นอกเขตเทศบาล
# 1500  2564           ภาคใต้  นอกเขตเทศบาล
# 1503  2564           ภาคใต้  นอกเขตเทศบาล
#
#                                   TYPE_EXPENSE  VALUE UNIT  \
# 1                         Consumption expenses  15328  บาท
# 2                 Food and drinks (no alcohol)   5660  บาท
# 5     Housing, home decorations and appliances   3553  บาท
# 15                        Consumption expenses  19340  บาท
# 16                Food and drinks (no alcohol)   6117  บาท
# ...                                        ...    ...  ...
# 1486              Food and drinks (no alcohol)   7689  บาท
# 1489  Housing, home decorations and appliances   4891  บาท
# 1499                      Consumption expenses  16834  บาท
# 1500              Food and drinks (no alcohol)   6991  บาท
# 1503  Housing, home decorations and appliances   3544  บาท
#
#                      SOURCE
# 1     สำนักงานสถิติแห่งชาติ
# 2     สำนักงานสถิติแห่งชาติ
# 5     สำนักงานสถิติแห่งชาติ
# 15    สำนักงานสถิติแห่งชาติ
# 16    สำนักงานสถิติแห่งชาติ
# ...                     ...
# 1486  สำนักงานสถิติแห่งชาติ
# 1489  สำนักงานสถิติแห่งชาติ
# 1499  สำนักงานสถิติแห่งชาติ
# 1500  สำนักงานสถิติแห่งชาติ
# 1503  สำนักงานสถิติแห่งชาติ
#
# [324 rows x 7 columns]

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=df2_filtered, x = 'TYPE_EXPENSE', y = 'VALUE',hue= 'YEAR',errorbar=None, palette="rocket_r")
plt.xlabel('Type of Expense')
plt.ylabel('Expense')
plt.title('Expense Sorted by Category')
plt.legend()
plt.show()
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
df3=pd.read_csv('https://github.com/Schwinnnnn/Data_schwin_year_3/raw/main/Bi/project2/euromonitor.csv',skiprows=5)
df3 = df3.drop(df3.index[44:])
df3
# Out:
#    Geography                                           Category  \
# 0   Thailand                Current Account Balance as % of GDP
# 1   Thailand                                      External debt
# 2   Thailand                          External debt as % of GDP
# 3   Thailand                                                GDP
# 4   Thailand                                  Gross Value Added
# 5   Thailand  GVA from Agriculture, Hunting, Forestry and Fi...
# 6   Thailand         GVA from Agriculture, Hunting and Forestry
# 7   Thailand                                   GVA from Fishing
# 8   Thailand  GVA from Mining and Quarrying; Manufacturing; ...
# 9   Thailand                      GVA from Mining and Quarrying
# 10  Thailand  GVA from Mining and Quarrying of Energy Produc...
# 11  Thailand  GVA from Mining and Quarrying Except Energy Pr...
# 12  Thailand                             GVA from Manufacturing
# 13  Thailand  GVA from Manufacture of Food Products; Beverag...
# 14  Thailand  GVA from Manufacture of Textiles and Textile P...
# 15  Thailand  GVA from Manufacture of Leather and Leather Pr...
# 16  Thailand     GVA from Manufacture of Wood and Wood Products
# 17  Thailand  GVA from Manufacture of Pulp, Paper and Paper ...
# 18  Thailand  GVA from Manufacture of Coke, Refined Petroleu...
# 19  Thailand  GVA from Manufacture of Chemicals, Chemical Pr...
# 20  Thailand  GVA from Manufacture of Rubber and Plastic Pro...
# 21  Thailand  GVA from Manufacture of Other Non-Metallic Min...
# 22  Thailand  GVA from Manufacture of Basic Metals and Fabri...
# 23  Thailand    GVA from Manufacture of Machinery and Equipment
# 24  Thailand  GVA from Manufacture of Electrical and Optical...
# 25  Thailand        GVA from Manufacture of Transport Equipment
# 26  Thailand                      GVA from Manufacturing N.E.C.
# 27  Thailand                              GVA from Construction
# 28  Thailand                        Manufacturing as a % of GVA
# 29  Thailand  GVA from Wholesale and Retail Trade; Repair of...
# 30  Thailand                             Services as a % of GVA
# 31  Thailand            GDP Measured at Purchasing Power Parity
# 32  Thailand                                    Real GDP Growth
# 33  Thailand                                       GDP Deflator
# 34  Thailand  GVA from Financial Intermediation, Real Estate...
# 35  Thailand  GVA from Public Administration and Defence; Ed...
# 36  Thailand  GVA from Activities of Households, Extraterrit...
# 37  Thailand              Private Final Consumption Expenditure
# 38  Thailand                        Gross National Income (GNI)
# 39  Thailand                        Industrial Production Index
# 40  Thailand                                          Inflation
# 41  Thailand                                       Money Supply
# 42  Thailand                Producer Price Index, Manufacturing
# 43  Thailand                                       Productivity
#
#                     Data Type                                        Unit  \
# 0   Socio-economic indicators                              % of total GDP
# 1   Socio-economic indicators                                 USD million
# 2   Socio-economic indicators                              % of total GDP
# 3   Socio-economic indicators                                 THB million
# 4   Socio-economic indicators                                 THB million
# 5   Socio-economic indicators                                 THB million
# 6   Socio-economic indicators                                 THB million
# 7   Socio-economic indicators                                 THB million
# 8   Socio-economic indicators                                 THB million
# 9   Socio-economic indicators                                 THB million
# 10  Socio-economic indicators                                 THB million
# 11  Socio-economic indicators                                 THB million
# 12  Socio-economic indicators                                 THB million
# 13  Socio-economic indicators                                 THB million
# 36      29,548.9      29,240.9      30,032.5      30,717.0
# 37   8,307,936.0   8,455,169.0   9,471,817.0  10,233,946.2
# 38  15,317,531.0  15,590,256.0  16,864,520.0  17,829,821.2
# 39          85.7          90.8          91.5          91.0
# 40        -0.847         1.232         6.078         1.227
# 41   2,529,837.0   2,883,750.0   2,973,786.0   3,095,737.0
# 42         100.4         105.3         114.5         112.5
# 43      12,877.1      13,050.0      12,904.2      13,046.5

# %%
df3.drop(columns=['Geography','Data Type','Unit','Current Constant','2022','2023'], inplace=True)
df3
# Out:
#                                              Category          2011  \
# 0                 Current Account Balance as % of GDP         2.542
# 1                                       External debt     104,333.5
# 2                           External debt as % of GDP          28.1
# 3                                                 GDP  11,306,906.0
# 4                                   Gross Value Added  11,306,906.0
# 5   GVA from Agriculture, Hunting, Forestry and Fi...   1,310,996.4
# 6          GVA from Agriculture, Hunting and Forestry   1,201,019.3
# 7                                    GVA from Fishing     109,977.1
# 8   GVA from Mining and Quarrying; Manufacturing; ...   3,998,196.2
# 9                       GVA from Mining and Quarrying     400,573.4
# 10  GVA from Mining and Quarrying of Energy Produc...     351,156.5
# 11  GVA from Mining and Quarrying Except Energy Pr...      49,416.9
# 12                             GVA from Manufacturing   3,294,335.5
# 13  GVA from Manufacture of Food Products; Beverag...     812,519.9
# 14  GVA from Manufacture of Textiles and Textile P...     210,006.2
# 15  GVA from Manufacture of Leather and Leather Pr...      39,697.0
# 16     GVA from Manufacture of Wood and Wood Products      35,581.0
# 17  GVA from Manufacture of Pulp, Paper and Paper ...      76,668.1
# 18  GVA from Manufacture of Coke, Refined Petroleu...     187,741.2
# 19  GVA from Manufacture of Chemicals, Chemical Pr...     276,316.3
# 20  GVA from Manufacture of Rubber and Plastic Pro...     238,101.3
# 21  GVA from Manufacture of Other Non-Metallic Min...     132,648.1
# 22  GVA from Manufacture of Basic Metals and Fabri...     160,035.2
# 23    GVA from Manufacture of Machinery and Equipment     183,337.2
# 24  GVA from Manufacture of Electrical and Optical...     478,809.5
# 25        GVA from Manufacture of Transport Equipment     290,631.3
# 26                      GVA from Manufacturing N.E.C.     172,243.2
# 27                              GVA from Construction     306,622.3
# 28                        Manufacturing as a % of GVA          29.1
# 29  GVA from Wholesale and Retail Trade; Repair of...   2,767,891.9
# 30                             Services as a % of GVA          50.2
# 31            GDP Measured at Purchasing Power Parity     912,790.0
# 32                                    Real GDP Growth         0.840
# 33                                       GDP Deflator         103.7
# 34  GVA from Financial Intermediation, Real Estate...   1,386,253.5
# 35  GVA from Public Administration and Defence; Ed...   1,516,443.6
# 36  GVA from Activities of Households, Extraterrit...      20,502.0
# 37              Private Final Consumption Expenditure   5,988,244.0
# 38                        Gross National Income (GNI)  11,034,184.0
# 39                        Industrial Production Index          85.0
# 40                                          Inflation         3.811
# 41                                       Money Supply   1,413,540.0
# 42                Producer Price Index, Manufacturing         107.6
# 43                                       Productivity      10,216.9
#
#             2012          2013          2014          2015          2016  \
# 0         -1.232        -2.101         2.859         6.918        10.507
# 1      130,746.8     141,932.9     141,714.7     131,078.2     140,030.9
# 2           32.9          33.8          34.8          32.7          33.9
# 3   15,488,664.0  16,373,343.0  16,889,174.0  15,661,146.0  16,166,597.0
# 4   15,488,664.0  16,373,343.0  16,889,174.0  15,661,146.0  16,166,597.0
# 5    1,340,380.6   1,382,445.2   1,413,836.9   1,401,018.3   1,446,720.6
# 6    1,218,092.0   1,254,220.0   1,283,538.1   1,267,026.6   1,306,658.2
# 7      122,288.5     128,225.2     130,298.8     133,991.7     140,062.4
# 8    5,029,541.3   5,278,829.5   5,254,825.1   4,780,216.1   5,207,193.2
# 9      407,750.0     440,310.6     435,026.2     341,741.1     370,879.1
# 10     331,764.8     367,195.0     359,237.1     270,386.2     299,055.9
# 11      75,985.2      73,115.7      75,789.1      71,354.9      71,823.2
# 12   4,196,177.0   4,386,236.8   4,341,360.3   4,007,508.1   4,398,350.2
# 13     917,149.9     935,666.1     948,958.5     937,413.7     995,717.8
# 14     201,024.8     205,061.2     199,227.8     166,882.5     157,337.1
# 15      45,081.2      47,460.6      48,606.8      40,236.7      43,245.1
# 16      47,239.0      46,239.9      47,476.1      49,890.6      54,320.5
# 17      84,445.1      86,018.7      84,135.7      82,335.6      85,371.6
# 18     442,005.0     499,803.4     493,283.0     374,124.9     459,763.8
# 19     391,884.2     435,810.6     415,944.4     388,884.9     452,716.4
# 20     327,002.5     301,831.7     287,225.0     268,293.6     291,676.8
# 21     144,299.4     151,031.3     156,515.8     149,690.5     154,488.5
# 22     194,243.5     203,313.0     196,776.0     191,161.2     220,109.0
# 23     241,651.6     253,782.4     251,583.3     248,965.5     262,036.4
# 24     527,561.0     545,019.9     546,924.3     545,564.7     584,696.0
# 25     438,466.6     477,048.9     465,068.9     359,687.6     412,916.7
# 26     194,123.0     198,149.1     199,634.7     204,376.0     223,954.4
# 27     399,890.8     415,517.6     424,725.8     426,876.3     442,695.3
# 28          27.1          26.8          25.7          25.6          27.2
# 29   4,403,319.6   4,768,111.9   5,108,376.6   4,382,913.2   4,290,724.9
# 30          56.1          56.6          57.8          57.6          55.9
# 31   1,205,839.0   1,286,976.0   1,337,761.0   1,272,999.0   1,349,714.0
# 32         4.178         4.223         2.115        -6.067         1.492
# 33         115.0         116.6         117.8         116.3         118.3
# 34   2,156,932.0   2,264,692.9   2,324,837.6   2,278,058.3   2,331,942.4
# 35   2,130,474.8   2,235,677.6   2,333,776.2   2,362,514.9   2,418,079.7
# 36      28,125.0      28,068.4      28,795.9      29,548.9      29,240.9
# 37   7,578,737.0   8,004,684.0   8,406,385.0   8,307,936.0   8,455,169.0
# 38  14,794,813.0  15,582,089.0  16,268,259.0  15,317,531.0  15,590,256.0
# 39          94.3          98.7          95.0          85.7          90.8
# 40         0.660         1.072         0.707        -0.847         1.232
# 41   2,038,861.0   2,095,155.0   2,214,392.0   2,529,837.0   2,883,750.0
# 42         103.1         103.5         102.0         100.4         105.3
# 43      12,965.3      13,377.2      13,741.8      12,877.1      13,050.0

# %%
filtered_df = df3.loc[df3.index.str.contains('Real GDP Growth|Inflation')]
# df3.Category.str.contains('Real GDP Growth|Inflation')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 filtered_df = df3.loc[df3.index.str.contains('Real GDP Growth|Inflation')]
#       2 # df3.Category.str.contains('Real GDP Growth|Inflation')
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\strings\accessor.py:191, in StringMethods.__init__(self, data)
#     188 def __init__(self, data) -> None:
#     189     from pandas.core.arrays.string_ import StringDtype
# --> 191     self._inferred_dtype = self._validate(data)
#     192     self._is_categorical = isinstance(data.dtype, CategoricalDtype)
#     193     self._is_string = isinstance(data.dtype, StringDtype)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\strings\accessor.py:245, in StringMethods._validate(data)
#     242 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     244 if inferred_dtype not in allowed_types:
# --> 245     raise AttributeError("Can only use .str accessor with string values!")
#     246 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!
