# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import ipywidgets as widgets
from IPython.display import display

# %% [markdown]
# <h1><span style="color:lightBLue;"><strong>Overview</strong></span></h1>
# <nav>
#     <ul>
#       <li><a href="#socio_econimic">Socio Econimic</a></li>
#       <li><a href="#expense">Expense</a></li>
#       <li><a href="#gdt_inflation">Real GDP Growth and Inflation</a></li>
#       <li><a href="#interest">Real Interest Rate</a></li>
#       <li><a href="#save_invest">Saving and Investment</a></li>
#       <li><a href="#summary">Summary</a></li>
#     </ul>
#   </nav>

# %% [markdown]
# <div id="socio_econimic">
# <h2><span style="color:lightBLue;"><strong>Socio Econimic</strong></span></h2>
# </div>

# %%
df1 = pd.read_csv("https://github.com/Schwinnnnn/Data_schwin_year_3/raw/main/Bi/project2/average_revenue_per_household.csv")
df1
# Out:
#     YEAR  CODE_SOCIO_ECON                                     SOCIO_ECONOMIC  \
# 0   2554                0                  รวมสถานะทางเศรษฐสังคมของครัวเรือน
# 1   2554                1  ผู้ถือครองทำการเกษตร การปลูกพืช การเลี้ยงสัตว์...
# 2   2554                2  ผู้ถือครองทำการเกษตร การปลูกพืช การเลี้ยงสัตว์...
# 3   2554                3  ผู้ทำการประมง ป่าไม้ ล่าสัตว์ หาของป่า และบริก...
# 4   2554                4           ผู้ดำเนินธุรกิจของตนเองที่ไม่ใช่การเกษตร
# ..   ...              ...                                                ...
# 61  2564                6                                         คนงานเกษตร
# 62  2564                7                                        คนงานทั่วไป
# 63  2564                8               เสมียนพนักงาน พนักงานขายและให้บริการ
# 64  2564                9                       ผู้ปฏิบัติงานในกระบวนการผลิต
# 65  2564               10                  ผู้ไม่ได้ปฏิบัติงานในเชิงเศรษฐกิจ
#
#     MONTHLY_INCOME  CURRENT_INCOME  MONEY_INCOME  FROM_WORK  CURRENT_TRANSFER  \
# 0            23236           22873         19712      16719              2527
# 1            20378           19935         16832      15405              1320
# 2            18238           17830         14967      13467              1476
# 3            12244           12107         10067       9342               695
# 4            30922           30544         27465      26273               864
# ..             ...             ...           ...        ...               ...
# 61           16059           15954         12645      11376              1250
# 62           17302           17197         13767      12451              1292
# 63           26668           26478         22094      20676              1331
# 64           24095           23947         20108      19043              1042
# 65           18202           17448         12657       1897             10203
#
#     PROPERTY_INCOME  NONMONEY_INCOME  NONCUR_M_INCOME UNIT  \
# 0               466             3161              363  บาท
# 1               107             3103              444  บาท
# 2                24             2863              408  บาท
# 3                31             2040              137  บาท
# 4               328             3079              379  บาท
# ..              ...              ...              ...  ...
# 61               18             3309              106  บาท
# 62               24             3431              105  บาท
# 63               86             4385              190  บาท
# 64               23             3838              148  บาท
# 65              557             4791              753  บาท
#
#                    SOURCE
# 0   สำนักงานสถิติแห่งชาติ
# 1   สำนักงานสถิติแห่งชาติ
# 2   สำนักงานสถิติแห่งชาติ
# 3   สำนักงานสถิติแห่งชาติ
# 4   สำนักงานสถิติแห่งชาติ
# ..                    ...
# 61  สำนักงานสถิติแห่งชาติ
# 62  สำนักงานสถิติแห่งชาติ
# 63  สำนักงานสถิติแห่งชาติ
# 64  สำนักงานสถิติแห่งชาติ
# 65  สำนักงานสถิติแห่งชาติ
#
# [66 rows x 13 columns]

# %%
df1['SOCIO_ECONOMIC'].replace({'รวมสถานะทางเศรษฐสังคมของครัวเรือน': 'Household status aggregation'}, inplace=True)
df1['SOCIO_ECONOMIC'].replace({'ผู้ถือครองทำการเกษตร การปลูกพืช การเลี้ยงสัตว์ และการเพาะเลี้ยงสัตวน้ำ ซึ่งที่ดินส่วนใหญ่เป็นของตนเอง': 'The landowner engages in agriculture on their own land'}, inplace=True)
df1['SOCIO_ECONOMIC'].replace({'ผู้ถือครองทำการเกษตร การปลูกพืช การเลี้ยงสัตว์ และการเพาะเลี้ยงสัตวน้ำ ซึ่งที่ดินส่วนใหญ่เช่าผู้อื่น/ที่สาธารณะ/อื่น ๆ': 'The landowner engages in agriculture on land that leased from others'}, inplace=True)
df1['SOCIO_ECONOMIC'].replace({'ผู้ทำการประมง ป่าไม้ ล่าสัตว์ หาของป่า และบริการทางการเกษตร': 'The individual engages in fishing, forestry and agricultural services'}, inplace=True)
df1['SOCIO_ECONOMIC'].replace({'ผู้ดำเนินธุรกิจของตนเองที่ไม่ใช่การเกษตร': 'The self-employed individual unrelated to agriculture'}, inplace=True)
df1['SOCIO_ECONOMIC'].replace({'ผู้ปฏิบัติงานวิชาชีพ นักวิชาการ และนักบริหารที่รับจ้าง': 'The professional worker is employed on a contractual basis'}, inplace=True)
df1['SOCIO_ECONOMIC'].replace({'คนงานเกษตร': 'The agricultural laborer'}, inplace=True)
df1['SOCIO_ECONOMIC'].replace({'คนงานทั่วไป': 'General laborer'}, inplace=True)
df1['SOCIO_ECONOMIC'].replace({'เสมียนพนักงาน พนักงานขายและให้บริการ': 'Sales and service staff'}, inplace=True)
df1['SOCIO_ECONOMIC'].replace({'ผู้ปฏิบัติงานในกระบวนการผลิต': 'Production workers'}, inplace=True)
df1['SOCIO_ECONOMIC'].replace({'ผู้ไม่ได้ปฏิบัติงานในเชิงเศรษฐกิจ': 'Non-economic workforce'}, inplace=True)
df1
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_46296\1588716534.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['SOCIO_ECONOMIC'].replace({'รวมสถานะทางเศรษฐสังคมของครัวเรือน': 'Household status aggregation'}, inplace=True)
#     YEAR  CODE_SOCIO_ECON                                     SOCIO_ECONOMIC  \
# 0   2554                0                       Household status aggregation
# 1   2554                1  The landowner engages in agriculture on their ...
# 2   2554                2  The landowner engages in agriculture on land t...
# 3   2554                3  The individual engages in fishing, forestry an...
# 4   2554                4  The self-employed individual unrelated to agri...
# ..   ...              ...                                                ...
# 61  2564                6                           The agricultural laborer
# 62  2564                7                                    General laborer
# 63  2564                8                            Sales and service staff
# 64  2564                9                                 Production workers
# 65  2564               10                             Non-economic workforce
#
#     MONTHLY_INCOME  CURRENT_INCOME  MONEY_INCOME  FROM_WORK  CURRENT_TRANSFER  \
# 0            23236           22873         19712      16719              2527
# 1            20378           19935         16832      15405              1320
# 2            18238           17830         14967      13467              1476
# 3            12244           12107         10067       9342               695
# 4            30922           30544         27465      26273               864
# ..             ...             ...           ...        ...               ...
# 61           16059           15954         12645      11376              1250
# 62           17302           17197         13767      12451              1292
# 63           26668           26478         22094      20676              1331
# 64           24095           23947         20108      19043              1042
# 65           18202           17448         12657       1897             10203
#
#     PROPERTY_INCOME  NONMONEY_INCOME  NONCUR_M_INCOME UNIT  \
# 0               466             3161              363  บาท
# 1               107             3103              444  บาท
# 2                24             2863              408  บาท
# 3                31             2040              137  บาท
# 4               328             3079              379  บาท
# ..              ...              ...              ...  ...
# 61               18             3309              106  บาท
# 62               24             3431              105  บาท
# 63               86             4385              190  บาท
# 64               23             3838              148  บาท
# 65              557             4791              753  บาท
#
#                    SOURCE
# 0   สำนักงานสถิติแห่งชาติ
# 1   สำนักงานสถิติแห่งชาติ
# 2   สำนักงานสถิติแห่งชาติ
# 3   สำนักงานสถิติแห่งชาติ
# 4   สำนักงานสถิติแห่งชาติ
# ..                    ...
# 61  สำนักงานสถิติแห่งชาติ
# 62  สำนักงานสถิติแห่งชาติ
# 63  สำนักงานสถิติแห่งชาติ
# 64  สำนักงานสถิติแห่งชาติ
# 65  สำนักงานสถิติแห่งชาติ
#
# [66 rows x 13 columns]

# %%
color = ["lightgray", "lightgray", "red", "red", "red", "red"]

def update_plot(selected_socio_economic, selected_column):
    plt.clf() 

    df_filtered = df1[df1['SOCIO_ECONOMIC'] == selected_socio_economic]

    mean_income_by_socioeconomic = df_filtered.groupby(['SOCIO_ECONOMIC', 'YEAR'])[selected_column].mean().reset_index()

    for socio_economic_group, group_data in mean_income_by_socioeconomic.groupby('SOCIO_ECONOMIC'):
        plt.bar(group_data['YEAR'], group_data[selected_column], label=socio_economic_group, color=color)

    plt.plot(mean_income_by_socioeconomic['YEAR'], mean_income_by_socioeconomic[selected_column], color='blue', marker='o', label='Line Graph')

    plt.xlabel('Year')
    plt.ylabel(f'Mean {selected_column}')
    plt.title(f'Mean {selected_column} by Socio-Economic Group Over the Years')
    plt.show()

socio_economic_values = df1['SOCIO_ECONOMIC'].unique().tolist()

column_values = ['MONTHLY_INCOME', 'CURRENT_INCOME', 'MONEY_INCOME', 'FROM_WORK', 'CURRENT_TRANSFER', 'PROPERTY_INCOME', 'NONMONEY_INCOME', 'NONCUR_M_INCOME']

dropdown_socio_economic = widgets.Dropdown(options=socio_economic_values, description='Socio-Economic:')
dropdown_column = widgets.Dropdown(options=column_values, description='Select Column:')

display(dropdown_socio_economic)
display(dropdown_column)

def on_dropdown_change(change):
    update_plot(dropdown_socio_economic.value, dropdown_column.value)

dropdown_socio_economic.observe(on_dropdown_change, names='value')
dropdown_column.observe(on_dropdown_change, names='value')

update_plot(socio_economic_values[0], column_values[0])
# Out:
# Dropdown(description='Socio-Economic:', options=('Household status aggregation', 'The landowner engages in agr…
# Dropdown(description='Select Column:', options=('MONTHLY_INCOME', 'CURRENT_INCOME', 'MONEY_INCOME', 'FROM_WORK…

# %% [markdown]
# <h4>ข้อมูลหลักที่ใช้ในการวิเคราะห์คือรายได้เฉลี่ยต่อเดือนของครัวเรือน<br />
# <br />โดยแยกตามแหล่งที่มาของรายได้ ในช่วงปี พ.ศ. 2554-2564 เราให้ความสำคัญกับรายได้ที่ได้มาจากการทำงาน เนื่องจากมีความสำคัญต่อความเจริญเติบโตของครัวเรือนมากที่สุด จากการวิเคราะห์กราฟพบว่ารายได้เฉลี่ยที่ได้มาจากการทำงานต่อครัวเรือนตั้งแต่ปี พ.ศ. 2558 มีแนวโน้มลดลงอย่างต่อเนื่อง ซึ่งเป็นสัญญาณที่บ่งบอกถึงความเสี่ยงและความทนทานของเศรษฐกิจในระยะยาว</h4>

# %% [markdown]
# <div id="expense">
# <h2><span style="color:lightBLue;"><strong>Expense</strong></span></h2>
# </div>

# %%
df2 = pd.read_csv("https://github.com/Schwinnnnn/Data_schwin_year_3/raw/main/Bi/project2/cost_per_household.csv")
df2
# Out:
#       YEAR           REGION          AREA  \
# 0     2554  ทั่วราชอาณาจักร           รวม
# 1     2554  ทั่วราชอาณาจักร           รวม
# 2     2554  ทั่วราชอาณาจักร           รวม
# 3     2554  ทั่วราชอาณาจักร           รวม
# 4     2554  ทั่วราชอาณาจักร           รวม
# ...    ...              ...           ...
# 1507  2564           ภาคใต้  นอกเขตเทศบาล
# 1508  2564           ภาคใต้  นอกเขตเทศบาล
# 1509  2564           ภาคใต้  นอกเขตเทศบาล
# 1510  2564           ภาคใต้  นอกเขตเทศบาล
# 1511  2564           ภาคใต้  นอกเขตเทศบาล
#
#                                   TYPE_EXPENSE  VALUE UNIT  \
# 0                   ค่าใช้จ่ายทั้งสิ้นต่อเดือน  17403  บาท
# 1               ค่าใช้จ่ายเพื่อการอุปโภคบริโภค  15328  บาท
# 2        อาหาร และเครื่องดื่ม (ไม่มีแอลกอฮอล์)   5660  บาท
# 3                    เครื่องดื่มที่มีแอลกอฮอล์     95  บาท
# 4                ยาสูบ หมาก ยานัตถุ์ และอื่นๆ      85  บาท
# ...                                        ...    ...  ...
# 1507                   การเดินทางและการสื่อสาร   4127  บาท
# 1508                                  การศึกษา    215  บาท
# 1509      การบันเทิง การอ่านและกิจกรรมทางศาสนา    223  บาท
# 1510                 การจัดงานพิธีในโอกาสพิเศษ    141  บาท
# 1511  ค่าใช้จ่ายที่ไม่เกี่ยวกับการอุปโภคบริโภค   2227  บาท
#
#                      SOURCE
# 0     สำนักงานสถิติแห่งชาติ
# 1     สำนักงานสถิติแห่งชาติ
# 2     สำนักงานสถิติแห่งชาติ
# 3     สำนักงานสถิติแห่งชาติ
# 4     สำนักงานสถิติแห่งชาติ
# ...                     ...
# 1507  สำนักงานสถิติแห่งชาติ
# 1508  สำนักงานสถิติแห่งชาติ
# 1509  สำนักงานสถิติแห่งชาติ
# 1510  สำนักงานสถิติแห่งชาติ
# 1511  สำนักงานสถิติแห่งชาติ
#
# [1512 rows x 7 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1512 entries, 0 to 1511
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   YEAR          1512 non-null   int64
#  1   REGION        1512 non-null   object
#  2   AREA          1512 non-null   object
#  3   TYPE_EXPENSE  1512 non-null   object
#  4   VALUE         1512 non-null   int64
#  5   UNIT          1512 non-null   object
#  6   SOURCE        1512 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 82.8+ KB

# %%
df2['TYPE_EXPENSE'].replace({'ค่าใช้จ่ายทั้งสิ้นต่อเดือน': 'Total expenses per month'}, inplace=True)
df2['TYPE_EXPENSE'].replace({'ค่าใช้จ่ายเพื่อการอุปโภคบริโภค': 'Consumption expenses'}, inplace=True)
df2['TYPE_EXPENSE'].replace({'อาหาร และเครื่องดื่ม (ไม่มีแอลกอฮอล์)': 'Food and drink (no alcohol)'}, inplace=True)
df2['TYPE_EXPENSE'].replace({'เครื่องดื่มที่มีแอลกอฮอล์': 'Alcoholic drinks'}, inplace=True)
df2['TYPE_EXPENSE'].replace({'ยาสูบ หมาก ยานัตถุ์ และอื่นๆ\xa0': 'Tobacco, betel nut, snuff, etc.'}, inplace=True)
df2['TYPE_EXPENSE'].replace({'ที่อยู่อาศัย เครื่องแต่งบ้าน และเครื่องใช้ต่าง ๆ': 'Housing, home decorations and various appliances.'}, inplace=True)
df2['TYPE_EXPENSE'].replace({'เครื่องนุ่งห่มและรองเท้า': 'Clothing and shoes'}, inplace=True)
df2['TYPE_EXPENSE'].replace({'ค่าใช้จ่ายส่วนบุคคล': 'Personal expenses'}, inplace=True)
df2['TYPE_EXPENSE'].replace({'เวชภัณฑ์และค่าตรวจรักษาพยาบาล': 'Medical supplies and medical examination costs'}, inplace=True)
df2['TYPE_EXPENSE'].replace({'การเดินทางและการสื่อสาร': 'Travel and communication'}, inplace=True)
df2['TYPE_EXPENSE'].replace({'การศึกษา': 'Education'}, inplace=True)
df2['TYPE_EXPENSE'].replace({'การบันเทิง การอ่านและกิจกรรมทางศาสนา': 'Entertainment, reading and religious activities'}, inplace=True)
df2['TYPE_EXPENSE'].replace({'การจัดงานพิธีในโอกาสพิเศษ': 'Organizing ceremonies on special occasions'}, inplace=True)
df2['TYPE_EXPENSE'].replace({'ค่าใช้จ่ายที่ไม่เกี่ยวกับการอุปโภคบริโภค': 'Non-consumption expenses'}, inplace=True)
df2
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_46296\1937713909.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2['TYPE_EXPENSE'].replace({'ค่าใช้จ่ายทั้งสิ้นต่อเดือน': 'Total expenses per month'}, inplace=True)
#       YEAR           REGION          AREA  \
# 0     2554  ทั่วราชอาณาจักร           รวม
# 1     2554  ทั่วราชอาณาจักร           รวม
# 2     2554  ทั่วราชอาณาจักร           รวม
# 3     2554  ทั่วราชอาณาจักร           รวม
# 4     2554  ทั่วราชอาณาจักร           รวม
# ...    ...              ...           ...
# 1507  2564           ภาคใต้  นอกเขตเทศบาล
# 1508  2564           ภาคใต้  นอกเขตเทศบาล
# 1509  2564           ภาคใต้  นอกเขตเทศบาล
# 1510  2564           ภาคใต้  นอกเขตเทศบาล
# 1511  2564           ภาคใต้  นอกเขตเทศบาล
#
#                                          TYPE_EXPENSE  VALUE UNIT  \
# 0                            Total expenses per month  17403  บาท
# 1                                Consumption expenses  15328  บาท
# 2                         Food and drink (no alcohol)   5660  บาท
# 3                                    Alcoholic drinks     95  บาท
# 4                     Tobacco, betel nut, snuff, etc.     85  บาท
# ...                                               ...    ...  ...
# 1507                         Travel and communication   4127  บาท
# 1508                                        Education    215  บาท
# 1509  Entertainment, reading and religious activities    223  บาท
# 1510       Organizing ceremonies on special occasions    141  บาท
# 1511                         Non-consumption expenses   2227  บาท
#
#                      SOURCE
# 0     สำนักงานสถิติแห่งชาติ
# 1     สำนักงานสถิติแห่งชาติ
# 2     สำนักงานสถิติแห่งชาติ
# 3     สำนักงานสถิติแห่งชาติ
# 4     สำนักงานสถิติแห่งชาติ
# ...                     ...
# 1507  สำนักงานสถิติแห่งชาติ
# 1508  สำนักงานสถิติแห่งชาติ
# 1509  สำนักงานสถิติแห่งชาติ
# 1510  สำนักงานสถิติแห่งชาติ
# 1511  สำนักงานสถิติแห่งชาติ
#
# [1512 rows x 7 columns]

# %%
def update_plot(type_of_expense):

    df2_filtered = df2[df2['TYPE_EXPENSE'] == type_of_expense]
    
    plt.figure(figsize=(16, 9))
    sns.barplot(data = df2_filtered, x = "TYPE_EXPENSE", y="VALUE" ,hue="YEAR",errorbar=None, palette="rocket_r")
    plt.xlabel('Type of Expense')
    plt.ylabel('Expense')
    plt.title('Expense Sorted by Category')
    plt.legend()
    plt.show()

type_of_expense_values = df2['TYPE_EXPENSE'].unique().tolist()

dropdown_type_of_expense = widgets.Dropdown(options=type_of_expense_values, description='Type of Expense:')
display(dropdown_type_of_expense)

def on_dropdown_change(change):
    update_plot(dropdown_type_of_expense.value)

dropdown_type_of_expense.observe(on_dropdown_change, names='value')

update_plot(type_of_expense_values[0])
# Out:
# Dropdown(description='Type of Expense:', options=('Total expenses per month', 'Consumption expenses', 'Food an…
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %% [markdown]
# <h4>ข้อมูลที่นำมาใช้ในการวิเคราะห์คือ ค่าใช้จ่ายเฉลี่ยต่อเดือนของครัวเรือนในช่วงปี พ.ศ. 2554-2564<br />
# <br />โดยได้เลือกส่วนที่สำคัญ 3 ด้าน ซึ่งประกอบด้วย
# <ul>
#       <li>ค่าใช้จ่ายเพื่อการอุปโภคบริโภค</li>
#       <li>ค่าใช้จ่ายสำหรับอาหารและเครื่องดื่ม (ไม่รวมแอลกอฮอล์)</li>
#       <li>ค่าใช้จ่ายในด้านที่อยู่อาศัยและเครื่องใช้ต่างๆ</li>
# </ul>โดยมีเหตุผลในการเลือกส่วนนี้เนื่องจากทั้ง 3 ส่วนนี้เป็นปัจจัยสำคัญที่มีผลต่อการเพิ่มรายจ่ายของครัวเรือน(ปัจจัย 4) โดยจากการวิเคราะห์กราฟพบว่าค่าใช้จ่ายเฉลี่ยต่อครัวเรือนกำลังเพิ่มสูงขึ้นและมีแนวโน้มที่จะเพิ่มขึ้นต่อไปในปีถัดไป ซึ่งสวนทางรายได้เฉลี่ยต่อเดือนของครัวเรือนที่ได้กล่าวถึงข้างต้น</h4>

# %% [markdown]
# <div id="gdt_inflation">
# <h2><span style="color:lightBLue;"><strong>Real GDP Growth and Inflation</strong></span></h2>
# </div>

# %%
df3=pd.read_csv('https://github.com/Schwinnnnn/Data_schwin_year_3/raw/main/Bi/project2/euromonitor.csv',skiprows=5, index_col='Category')
df3 = df3.drop(df3.index[44:])
df3.drop(columns=['Geography','Data Type','Unit','Current Constant','2022','2023'], inplace=True)
df3
# Out:
#                                                             2011  \
# Category
# Current Account Balance as % of GDP                        2.542
# External debt                                          104,333.5
# External debt as % of GDP                                   28.1
# GDP                                                 11,306,906.0
# Gross Value Added                                   11,306,906.0
# GVA from Agriculture, Hunting, Forestry and Fis...   1,310,996.4
# GVA from Agriculture, Hunting and Forestry           1,201,019.3
# GVA from Fishing                                       109,977.1
# GVA from Mining and Quarrying; Manufacturing; E...   3,998,196.2
# GVA from Mining and Quarrying                          400,573.4
# GVA from Mining and Quarrying of Energy Produci...     351,156.5
# GVA from Mining and Quarrying Except Energy Pro...      49,416.9
# GVA from Manufacturing                               3,294,335.5
# GVA from Manufacture of Food Products; Beverage...     812,519.9
# GVA from Manufacture of Textiles and Textile Pr...     210,006.2
# GVA from Manufacture of Leather and Leather Pro...      39,697.0
# GVA from Manufacture of Wood and Wood Products          35,581.0
# GVA from Manufacture of Pulp, Paper and Paper P...      76,668.1
# GVA from Manufacture of Coke, Refined Petroleum...     187,741.2
# GVA from Manufacture of Chemicals, Chemical Pro...     276,316.3
# GVA from Manufacture of Rubber and Plastic Prod...     238,101.3
# GVA from Manufacture of Other Non-Metallic Mine...     132,648.1
# GVA from Manufacture of Basic Metals and Fabric...     160,035.2
# GVA from Manufacture of Machinery and Equipment        183,337.2
# GVA from Manufacture of Electrical and Optical ...     478,809.5
# GVA from Manufacture of Transport Equipment            290,631.3
# GVA from Manufacturing N.E.C.                          172,243.2
# GVA from Construction                                  306,622.3
# Manufacturing as a % of GVA                                 29.1
# GVA from Wholesale and Retail Trade; Repair of ...   2,767,891.9
# Services as a % of GVA                                      50.2
# GDP Measured at Purchasing Power Parity                912,790.0
# Real GDP Growth                                            0.840
# GDP Deflator                                               103.7
# GVA from Financial Intermediation, Real Estate,...   1,386,253.5
# GVA from Public Administration and Defence; Edu...   1,516,443.6
# GVA from Activities of Households, Extraterrito...      20,502.0
# Private Final Consumption Expenditure                5,988,244.0
# Gross National Income (GNI)                         11,034,184.0
# Industrial Production Index                                 85.0
# Inflation                                                  3.811
# Money Supply                                         1,413,540.0
# Producer Price Index, Manufacturing                        107.6
# Productivity                                            10,216.9
#
#                                                             2012  \
# Category
# Current Account Balance as % of GDP                       -1.232
# External debt                                          130,746.8
# External debt as % of GDP                                   32.9
# GDP                                                 12,357,342.0
# Gross Value Added                                   12,357,342.0
# GVA from Agriculture, Hunting, Forestry and Fis...   1,421,962.5
# GVA from Agriculture, Hunting and Forestry           1,308,902.4
# GVA from Fishing                                       113,060.0
# GVA from Mining and Quarrying; Manufacturing; E...   4,284,184.4
# GVA from Mining and Quarrying                          483,425.2
# GVA from Mining and Quarrying of Energy Produci...     428,998.3
# GVA from Mining and Quarrying Except Energy Pro...      54,426.9
# GVA from Manufacturing                               3,473,817.1
# GVA from Manufacture of Food Products; Beverage...     814,847.0
# GVA from Manufacture of Textiles and Textile Pr...     198,494.9
# GVA from Manufacture of Leather and Leather Pro...      32,956.0
# GVA from Manufacture of Wood and Wood Products          37,101.3
# GVA from Manufacture of Pulp, Paper and Paper P...      79,411.5
# GVA from Manufacture of Coke, Refined Petroleum...     203,996.4
# GVA from Manufacture of Chemicals, Chemical Pro...     292,122.0
# GVA from Manufacture of Rubber and Plastic Prod...     249,528.2
# GVA from Manufacture of Other Non-Metallic Mine...     142,570.3
# GVA from Manufacture of Basic Metals and Fabric...     165,542.9
# GVA from Manufacture of Machinery and Equipment        192,799.7
# GVA from Manufacture of Electrical and Optical ...     464,677.3
# GVA from Manufacture of Transport Equipment            418,139.9
# GVA from Manufacturing N.E.C.                          181,629.9
# GVA from Construction                                  340,956.1
# Manufacturing as a % of GVA                                 28.1
# GVA from Wholesale and Retail Trade; Repair of ...   3,047,412.0
# Services as a % of GVA                                      50.9
# GDP Measured at Purchasing Power Parity              1,008,787.0
# Real GDP Growth                                            7.243
# GDP Deflator                                               105.7
# GVA from Financial Intermediation, Real Estate,...   1,585,012.5
# GVA from Public Administration and Defence; Edu...   1,655,192.5
# GVA from Activities of Households, Extraterrito...      22,622.0
# Private Final Consumption Expenditure                6,582,558.0
# Gross National Income (GNI)                         11,791,139.0
# Industrial Production Index                                 91.4
# Inflation                                                  3.013
# Money Supply                                         1,597,148.0
# Producer Price Index, Manufacturing                        108.5
# Productivity                                            10,818.9
#
#                                                             2013  \
# Category
# Current Account Balance as % of GDP                       -2.101
# External debt                                          141,932.9
# External debt as % of GDP                                   33.8
# GDP                                                 12,915,158.0
# Gross Value Added                                   12,915,158.0
# GVA from Agriculture, Hunting, Forestry and Fis...   1,462,624.5
# GVA from Agriculture, Hunting and Forestry           1,359,884.6
# GVA from Fishing                                       102,740.0
# GVA from Mining and Quarrying; Manufacturing; E...   4,431,117.6
# GVA from Mining and Quarrying                          496,561.8
# GVA from Mining and Quarrying of Energy Produci...     442,832.7
# GVA from Mining and Quarrying Except Energy Pro...      53,729.1
# GVA from Manufacturing                               3,581,714.9
# GVA from Manufacture of Food Products; Beverage...     839,305.9
# GVA from Manufacture of Textiles and Textile Pr...     196,803.8
# GVA from Manufacture of Leather and Leather Pro...      39,756.5
# GVA from Manufacture of Wood and Wood Products          38,720.6
# GVA from Manufacture of Pulp, Paper and Paper P...      78,560.2
# GVA from Manufacture of Coke, Refined Petroleum...     238,431.0
# GVA from Manufacture of Chemicals, Chemical Pro...     306,704.7
# GVA from Manufacture of Rubber and Plastic Prod...     251,667.2
# GVA from Manufacture of Other Non-Metallic Mine...     152,449.0
# GVA from Manufacture of Basic Metals and Fabric...     165,974.5
# GVA from Manufacture of Machinery and Equipment        208,035.1
# GVA from Manufacture of Electrical and Optical ...     469,638.4
# GVA from Manufacture of Transport Equipment            415,110.3
# GVA from Manufacturing N.E.C.                          180,557.8
# GVA from Construction                                  344,785.9
# Manufacturing as a % of GVA                                 27.7
# GVA from Wholesale and Retail Trade; Repair of ...   3,167,745.0
# Services as a % of GVA                                      51.5
# GDP Measured at Purchasing Power Parity              1,049,948.0
# Real GDP Growth                                            2.687
# GDP Deflator                                               107.6
# GVA from Financial Intermediation, Real Estate,...   1,739,300.5
# GVA from Public Administration and Defence; Edu...   1,746,287.5
# GVA from Activities of Households, Extraterrito...      23,297.0
# Private Final Consumption Expenditure                6,787,206.0
# Gross National Income (GNI)                         12,089,673.0
# Industrial Production Index                                 93.3
# Inflation                                                  2.185
# Money Supply                                         1,661,304.0
# Producer Price Index, Manufacturing                        108.0
# Productivity                                            11,123.7
#
#                                                             2014  \
# Category
# Current Account Balance as % of GDP                        2.859
# External debt                                          141,714.7
# External debt as % of GDP                                   34.8
# GDP                                                 13,230,304.0
# Gross Value Added                                   13,230,304.0
# GVA from Agriculture, Hunting, Forestry and Fis...   1,335,153.3
# GVA from Agriculture, Hunting and Forestry           1,225,199.3
# GVA from Fishing                                       109,954.0
# GVA from Mining and Quarrying; Manufacturing; E...   4,536,446.0
# GVA from Mining and Quarrying                          495,627.1
# GVA from Mining and Quarrying of Energy Produci...     440,566.1
# GVA from Mining and Quarrying Except Energy Pro...      55,061.0
# GVA from Manufacturing                               3,667,582.8
# GVA from Manufacture of Food Products; Beverage...     858,791.5
# GVA from Manufacture of Textiles and Textile Pr...     199,104.1
# GVA from Manufacture of Leather and Leather Pro...      43,400.9
# GVA from Manufacture of Wood and Wood Products          42,758.9
# GVA from Manufacture of Pulp, Paper and Paper P...      79,809.1
# GVA from Manufacture of Coke, Refined Petroleum...     271,536.4
# GVA from Manufacture of Chemicals, Chemical Pro...     327,371.5
# GVA from Manufacture of Rubber and Plastic Prod...     246,367.0
# GVA from Manufacture of Other Non-Metallic Mine...     151,789.5
# GVA from Manufacture of Basic Metals and Fabric...     173,592.6
# GVA from Manufacture of Machinery and Equipment        205,194.2
# GVA from Manufacture of Electrical and Optical ...     528,755.3
# GVA from Manufacture of Transport Equipment            360,023.2
# GVA from Manufacturing N.E.C.                          179,088.6
# GVA from Construction                                  337,042.1
# Manufacturing as a % of GVA                                 27.7
# GVA from Wholesale and Retail Trade; Repair of ...   3,310,670.8
# Services as a % of GVA                                      52.9
# GDP Measured at Purchasing Power Parity              1,059,446.0
# Real GDP Growth                                            0.984
# GDP Deflator                                               109.2
# GVA from Financial Intermediation, Real Estate,...   1,841,290.4
# GVA from Public Administration and Defence; Edu...   1,844,926.4
# GVA from Activities of Households, Extraterrito...      24,775.0
# Private Final Consumption Expenditure                6,958,639.0
# Gross National Income (GNI)                         12,549,606.0
# Industrial Production Index                                 90.1
# Inflation                                                  1.896
# Money Supply                                         1,682,469.0
# Producer Price Index, Manufacturing                        108.2
# Productivity                                            11,481.7
#
#                                                             2015  \
# Category
# Current Account Balance as % of GDP                        6.918
# External debt                                          131,078.2
# External debt as % of GDP                                   32.7
# GDP                                                 13,743,480.0
# Gross Value Added                                   13,743,480.0
# GVA from Agriculture, Hunting, Forestry and Fis...   1,235,919.8
# GVA from Agriculture, Hunting and Forestry           1,133,108.2
# GVA from Fishing                                       102,811.6
# GVA from Mining and Quarrying; Manufacturing; E...   4,598,112.0
# GVA from Mining and Quarrying                          431,314.3
# GVA from Mining and Quarrying of Energy Produci...     368,568.6
# GVA from Mining and Quarrying Except Energy Pro...      62,745.7
# GVA from Manufacturing                               3,779,939.0
# GVA from Manufacture of Food Products; Beverage...     872,448.5
# GVA from Manufacture of Textiles and Textile Pr...     193,758.0
# GVA from Manufacture of Leather and Leather Pro...      40,900.1
# GVA from Manufacture of Wood and Wood Products          43,400.4
# GVA from Manufacture of Pulp, Paper and Paper P...      81,748.7
# GVA from Manufacture of Coke, Refined Petroleum...     312,523.6
# GVA from Manufacture of Chemicals, Chemical Pro...     358,107.7
# GVA from Manufacture of Rubber and Plastic Prod...     265,225.9
# GVA from Manufacture of Other Non-Metallic Mine...     148,989.6
# GVA from Manufacture of Basic Metals and Fabric...     170,437.9
# GVA from Manufacture of Machinery and Equipment        219,949.0
# GVA from Manufacture of Electrical and Optical ...     508,191.3
# GVA from Manufacture of Transport Equipment            382,150.3
# GVA from Manufacturing N.E.C.                          182,108.0
# GVA from Construction                                  379,841.5
# Manufacturing as a % of GVA                                 27.5
# GVA from Wholesale and Retail Trade; Repair of ...   3,635,962.9
# Services as a % of GVA                                      54.6
# GDP Measured at Purchasing Power Parity              1,087,227.0
# Real GDP Growth                                            3.134
# GDP Deflator                                               109.9
# GVA from Financial Intermediation, Real Estate,...   1,930,757.5
# GVA from Public Administration and Defence; Edu...   1,935,083.4
# GVA from Activities of Households, Extraterrito...      27,802.9
# Private Final Consumption Expenditure                7,056,549.0
# Gross National Income (GNI)                         13,034,507.0
# Industrial Production Index                                 90.2
# Inflation                                                 -0.900
# Money Supply                                         1,778,078.0
# Producer Price Index, Manufacturing                        103.0
# Productivity                                            11,856.1
#
#                                                             2016  \
# Category
# Current Account Balance as % of GDP                       10.507
# External debt                                          140,030.9
# External debt as % of GDP                                   33.9
# GDP                                                 14,590,337.0
# Gross Value Added                                   14,590,337.0
# GVA from Agriculture, Hunting, Forestry and Fis...   1,240,874.0
# GVA from Agriculture, Hunting and Forestry           1,126,393.8
# GVA from Fishing                                       114,480.2
# GVA from Mining and Quarrying; Manufacturing; E...   4,815,691.9
# GVA from Mining and Quarrying                          400,141.4
# GVA from Mining and Quarrying of Energy Produci...     321,400.4
# GVA from Mining and Quarrying Except Energy Pro...      78,741.0
# GVA from Manufacturing                               3,996,386.9
# GVA from Manufacture of Food Products; Beverage...     938,713.1
# GVA from Manufacture of Textiles and Textile Pr...     196,965.3
# GVA from Manufacture of Leather and Leather Pro...      42,624.9
# GVA from Manufacture of Wood and Wood Products          47,107.8
# GVA from Manufacture of Pulp, Paper and Paper P...      84,262.5
# GVA from Manufacture of Coke, Refined Petroleum...     399,489.5
# GVA from Manufacture of Chemicals, Chemical Pro...     355,098.7
# GVA from Manufacture of Rubber and Plastic Prod...     282,835.1
# GVA from Manufacture of Other Non-Metallic Mine...     149,811.5
# GVA from Manufacture of Basic Metals and Fabric...     181,906.1
# GVA from Manufacture of Machinery and Equipment        224,099.8
# GVA from Manufacture of Electrical and Optical ...     490,999.6
# GVA from Manufacture of Transport Equipment            414,480.9
# GVA from Manufacturing N.E.C.                          187,991.8
# GVA from Construction                                  404,492.4
# Manufacturing as a % of GVA                                 27.4
# GVA from Wholesale and Retail Trade; Repair of ...   4,018,077.4
# Services as a % of GVA                                      55.5
# GDP Measured at Purchasing Power Parity              1,146,041.0
# Real GDP Growth                                            3.435
# GDP Deflator                                               112.8
# GVA from Financial Intermediation, Real Estate,...   2,044,771.0
# GVA from Public Administration and Defence; Edu...   2,038,216.4
# GVA from Activities of Households, Extraterrito...      28,214.0
# Private Final Consumption Expenditure                7,296,548.0
# Gross National Income (GNI)                         13,904,973.0
# Industrial Production Index                                 92.9
# Inflation                                                  0.188
# Money Supply                                         1,864,192.0
# Producer Price Index, Manufacturing                        101.9
# Productivity                                            12,366.7
#
#                                                             2017  \
# Category
# Current Account Balance as % of GDP                        9.632
# External debt                                          155,948.9
# External debt as % of GDP                                   34.2
# GDP                                                 15,488,664.0
# Gross Value Added                                   15,488,664.0
# GVA from Agriculture, Hunting, Forestry and Fis...   1,340,380.6
# GVA from Agriculture, Hunting and Forestry           1,218,092.0
# GVA from Fishing                                       122,288.5
# GVA from Mining and Quarrying; Manufacturing; E...   5,029,541.3
# GVA from Mining and Quarrying                          407,750.0
# GVA from Mining and Quarrying of Energy Produci...     331,764.8
# GVA from Mining and Quarrying Except Energy Pro...      75,985.2
# GVA from Manufacturing                               4,196,177.0
# GVA from Manufacture of Food Products; Beverage...     917,149.9
# GVA from Manufacture of Textiles and Textile Pr...     201,024.8
# GVA from Manufacture of Leather and Leather Pro...      45,081.2
# GVA from Manufacture of Wood and Wood Products          47,239.0
# GVA from Manufacture of Pulp, Paper and Paper P...      84,445.1
# GVA from Manufacture of Coke, Refined Petroleum...     442,005.0
# GVA from Manufacture of Chemicals, Chemical Pro...     391,884.2
# GVA from Manufacture of Rubber and Plastic Prod...     327,002.5
# GVA from Manufacture of Other Non-Metallic Mine...     144,299.4
# GVA from Manufacture of Basic Metals and Fabric...     194,243.5
# GVA from Manufacture of Machinery and Equipment        241,651.6
# GVA from Manufacture of Electrical and Optical ...     527,561.0
# GVA from Manufacture of Transport Equipment            438,466.6
# GVA from Manufacturing N.E.C.                          194,123.0
# GVA from Construction                                  399,890.8
# Manufacturing as a % of GVA                                 27.1
# GVA from Wholesale and Retail Trade; Repair of ...   4,403,319.6
# Services as a % of GVA                                      56.1
# GDP Measured at Purchasing Power Parity              1,205,839.0
# Real GDP Growth                                            4.178
# GDP Deflator                                               115.0
# GVA from Financial Intermediation, Real Estate,...   2,156,932.0
# GVA from Public Administration and Defence; Edu...   2,130,474.8
# GVA from Activities of Households, Extraterrito...      28,125.0
# Private Final Consumption Expenditure                7,578,737.0
# Gross National Income (GNI)                         14,794,813.0
# Industrial Production Index                                 94.3
# Inflation                                                  0.660
# Money Supply                                         2,038,861.0
# Producer Price Index, Manufacturing                        103.1
# Productivity                                            12,965.3
#
#                                                             2018  \
# Category
# Current Account Balance as % of GDP                        5.620
# External debt                                          163,103.0
# External debt as % of GDP                                   32.2
# GDP                                                 16,373,343.0
# Gross Value Added                                   16,373,343.0
# GVA from Agriculture, Hunting, Forestry and Fis...   1,382,445.2
# GVA from Agriculture, Hunting and Forestry           1,254,220.0
# GVA from Fishing                                       128,225.2
# GVA from Mining and Quarrying; Manufacturing; E...   5,278,829.5
# GVA from Mining and Quarrying                          440,310.6
# GVA from Mining and Quarrying of Energy Produci...     367,195.0
# GVA from Mining and Quarrying Except Energy Pro...      73,115.7
# GVA from Manufacturing                               4,386,236.8
# GVA from Manufacture of Food Products; Beverage...     935,666.1
# GVA from Manufacture of Textiles and Textile Pr...     205,061.2
# GVA from Manufacture of Leather and Leather Pro...      47,460.6
# GVA from Manufacture of Wood and Wood Products          46,239.9
# GVA from Manufacture of Pulp, Paper and Paper P...      86,018.7
# GVA from Manufacture of Coke, Refined Petroleum...     499,803.4
# GVA from Manufacture of Chemicals, Chemical Pro...     435,810.6
# GVA from Manufacture of Rubber and Plastic Prod...     301,831.7
# GVA from Manufacture of Other Non-Metallic Mine...     151,031.3
# GVA from Manufacture of Basic Metals and Fabric...     203,313.0
# GVA from Manufacture of Machinery and Equipment        253,782.4
# GVA from Manufacture of Electrical and Optical ...     545,019.9
# GVA from Manufacture of Transport Equipment            477,048.9
# GVA from Manufacturing N.E.C.                          198,149.1
# GVA from Construction                                  415,517.6
# Manufacturing as a % of GVA                                 26.8
# GVA from Wholesale and Retail Trade; Repair of ...   4,768,111.9
# Services as a % of GVA                                      56.6
# GDP Measured at Purchasing Power Parity              1,286,976.0
# Real GDP Growth                                            4.223
# GDP Deflator                                               116.6
# GVA from Financial Intermediation, Real Estate,...   2,264,692.9
# GVA from Public Administration and Defence; Edu...   2,235,677.6
# GVA from Activities of Households, Extraterrito...      28,068.4
# Private Final Consumption Expenditure                8,004,684.0
# Gross National Income (GNI)                         15,582,089.0
# Industrial Production Index                                 98.7
# Inflation                                                  1.072
# Money Supply                                         2,095,155.0
# Producer Price Index, Manufacturing                        103.5
# Productivity                                            13,377.2
#
#                                                             2019  \
# Category
# Current Account Balance as % of GDP                        7.034
# External debt                                          171,884.9
# External debt as % of GDP                                   31.6
# GDP                                                 16,889,174.0
# Gross Value Added                                   16,889,174.0
# GVA from Agriculture, Hunting, Forestry and Fis...   1,413,836.9
# GVA from Agriculture, Hunting and Forestry           1,283,538.1
# GVA from Fishing                                       130,298.8
# GVA from Mining and Quarrying; Manufacturing; E...   5,254,825.1
# GVA from Mining and Quarrying                          435,026.2
# GVA from Mining and Quarrying of Energy Produci...     359,237.1
# GVA from Mining and Quarrying Except Energy Pro...      75,789.1
# GVA from Manufacturing                               4,341,360.3
# GVA from Manufacture of Food Products; Beverage...     948,958.5
# GVA from Manufacture of Textiles and Textile Pr...     199,227.8
# GVA from Manufacture of Leather and Leather Pro...      48,606.8
# GVA from Manufacture of Wood and Wood Products          47,476.1
# GVA from Manufacture of Pulp, Paper and Paper P...      84,135.7
# GVA from Manufacture of Coke, Refined Petroleum...     493,283.0
# GVA from Manufacture of Chemicals, Chemical Pro...     415,944.4
# GVA from Manufacture of Rubber and Plastic Prod...     287,225.0
# GVA from Manufacture of Other Non-Metallic Mine...     156,515.8
# GVA from Manufacture of Basic Metals and Fabric...     196,776.0
# GVA from Manufacture of Machinery and Equipment        251,583.3
# GVA from Manufacture of Electrical and Optical ...     546,924.3
# GVA from Manufacture of Transport Equipment            465,068.9
# GVA from Manufacturing N.E.C.                          199,634.7
# GVA from Construction                                  424,725.8
# Manufacturing as a % of GVA                                 25.7
# GVA from Wholesale and Retail Trade; Repair of ...   5,108,376.6
# Services as a % of GVA                                      57.8
# GDP Measured at Purchasing Power Parity              1,337,761.0
# Real GDP Growth                                            2.115
# GDP Deflator                                               117.8
# GVA from Financial Intermediation, Real Estate,...   2,324,837.6
# GVA from Public Administration and Defence; Edu...   2,333,776.2
# GVA from Activities of Households, Extraterrito...      28,795.9
# Private Final Consumption Expenditure                8,406,385.0
# Gross National Income (GNI)                         16,268,259.0
# Industrial Production Index                                 95.0
# Inflation                                                  0.707
# Money Supply                                         2,214,392.0
# Producer Price Index, Manufacturing                        102.0
# Productivity                                            13,741.8
#
#                                                             2020          2021
# Category
# Current Account Balance as % of GDP                        4.184        -2.032
# External debt                                          190,712.7     196,274.0
# External debt as % of GDP                                   38.1          38.8
# GDP                                                 15,661,146.0  16,166,597.0
# Gross Value Added                                   15,661,146.0  16,166,597.0
# GVA from Agriculture, Hunting, Forestry and Fis...   1,401,018.3   1,446,720.6
# GVA from Agriculture, Hunting and Forestry           1,267,026.6   1,306,658.2
# GVA from Fishing                                       133,991.7     140,062.4
# GVA from Mining and Quarrying; Manufacturing; E...   4,780,216.1   5,207,193.2
# GVA from Mining and Quarrying                          341,741.1     370,879.1
# GVA from Mining and Quarrying of Energy Produci...     270,386.2     299,055.9
# GVA from Mining and Quarrying Except Energy Pro...      71,354.9      71,823.2
# GVA from Manufacturing                               4,007,508.1   4,398,350.2
# GVA from Manufacture of Food Products; Beverage...     937,413.7     995,717.8
# GVA from Manufacture of Textiles and Textile Pr...     166,882.5     157,337.1
# GVA from Manufacture of Leather and Leather Pro...      40,236.7      43,245.1
# GVA from Manufacture of Wood and Wood Products          49,890.6      54,320.5
# GVA from Manufacture of Pulp, Paper and Paper P...      82,335.6      85,371.6
# GVA from Manufacture of Coke, Refined Petroleum...     374,124.9     459,763.8
# GVA from Manufacture of Chemicals, Chemical Pro...     388,884.9     452,716.4
# GVA from Manufacture of Rubber and Plastic Prod...     268,293.6     291,676.8
# GVA from Manufacture of Other Non-Metallic Mine...     149,690.5     154,488.5
# GVA from Manufacture of Basic Metals and Fabric...     191,161.2     220,109.0
# GVA from Manufacture of Machinery and Equipment        248,965.5     262,036.4
# GVA from Manufacture of Electrical and Optical ...     545,564.7     584,696.0
# GVA from Manufacture of Transport Equipment            359,687.6     412,916.7
# GVA from Manufacturing N.E.C.                          204,376.0     223,954.4
# GVA from Construction                                  426,876.3     442,695.3
# Manufacturing as a % of GVA                                 25.6          27.2
# GVA from Wholesale and Retail Trade; Repair of ...   4,382,913.2   4,290,724.9
# Services as a % of GVA                                      57.6          55.9
# GDP Measured at Purchasing Power Parity              1,272,999.0   1,349,714.0
# Real GDP Growth                                           -6.067         1.492
# GDP Deflator                                               116.3         118.3
# GVA from Financial Intermediation, Real Estate,...   2,278,058.3   2,331,942.4
# GVA from Public Administration and Defence; Edu...   2,362,514.9   2,418,079.7
# GVA from Activities of Households, Extraterrito...      29,548.9      29,240.9
# Private Final Consumption Expenditure                8,307,936.0   8,455,169.0
# Gross National Income (GNI)                         15,317,531.0  15,590,256.0
# Industrial Production Index                                 85.7          90.8
# Inflation                                                 -0.847         1.232
# Money Supply                                         2,529,837.0   2,883,750.0
# Producer Price Index, Manufacturing                        100.4         105.3
# Productivity                                            12,877.1      13,050.0

# %%
filtered_df = df3.loc[df3.index.str.contains('Real GDP Growth|Inflation')]

filtered_df['Category'] = filtered_df.index.str.extract('(Real GDP Growth|Inflation)', expand=False)

filtered_df.reset_index(drop=True, inplace=True)

melted_data = filtered_df.melt(id_vars='Category', var_name='Year', value_name='Percent Growth')
melted_data
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_46296\1438648946.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Category'] = filtered_df.index.str.extract('(Real GDP Growth|Inflation)', expand=False)
#            Category  Year Percent Growth
# 0   Real GDP Growth  2011          0.840
# 1         Inflation  2011          3.811
# 2   Real GDP Growth  2012          7.243
# 3         Inflation  2012          3.013
# 4   Real GDP Growth  2013          2.687
# 5         Inflation  2013          2.185
# 6   Real GDP Growth  2014          0.984
# 7         Inflation  2014          1.896
# 8   Real GDP Growth  2015          3.134
# 9         Inflation  2015         -0.900
# 10  Real GDP Growth  2016          3.435
# 11        Inflation  2016          0.188
# 12  Real GDP Growth  2017          4.178
# 13        Inflation  2017          0.660
# 14  Real GDP Growth  2018          4.223
# 15        Inflation  2018          1.072
# 16  Real GDP Growth  2019          2.115
# 17        Inflation  2019          0.707
# 18  Real GDP Growth  2020         -6.067
# 19        Inflation  2020         -0.847
# 20  Real GDP Growth  2021          1.492
# 21        Inflation  2021          1.232

# %%
import matplotlib.pyplot as plt

melted_data['Year'] = melted_data['Year'].astype(int)

melted_data['Percent Growth'] = melted_data['Percent Growth'].astype(float)

plt.figure(figsize=(10, 6))
ax = plt.gca()

melted_data[melted_data['Category'] == 'Real GDP Growth'].plot(kind='line', x='Year', y='Percent Growth', 
                                                               marker='o', label='Real GDP Growth', ax=ax)

melted_data[melted_data['Category'] == 'Inflation'].plot(kind='line', x='Year', y='Percent Growth', 
                                                         marker='o', label='Inflation', ax=ax)

plt.title('Trend of Real GDP Growth and Inflation (2011-2021)')
plt.xlabel('Year')
plt.ylabel('Percent Growth')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.axhline(y=0, color='black', linestyle='-', linewidth=.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h4>ข้อมูลที่นำมาใช้ในการวิเคราะห์คือ ข้อมูลGDPและอัตราเงินเฟ้อของปรพะเทศไทย ในช่วงปี 2011-2021<br />
# <br />เพื่อศึกษาภาพรวมเศรษฐกิจของประเทศไทย
# จากกราฟนี้จะเห็นได้ว่า แม้ในปี2021 สภาพเศรษฐกิจกำลังอยู่ในสภาวะฟื้นตัว แต่โดยภาพรวมของกราฟก็ยังแสดงให้เห็นถึงความผันผวนและยากที่จะคาดเดาอนาคตฅ
# นอกจากนีจากการหาข้อมูลเพิ่มเติมทำให้ทราบว่า ตอนนี้เศรฐกิจโลกกำลังเผชิญ <a href="https://www.thairath.co.th/money/economics/analysis/2590936"target="_blank">"วิกฤติเงินเฟ้อ ค่าครองชีพที่พุ่งสูงขึ้น ภาพรวมของเศรษฐกิจโลกที่พลิกคว่ำคะมำหงายจากช่วงฟื้นฟูดิ่งสู่ภาวะถดถอย รวมทั้งความผันผวนที่รุนแรงขึ้นในตลาดการเงินทั่วโลก"</a><br />
# <br />
# จากการที่รายได้เฉลี่ยต่อครัวเรือนลดลงและค่าใช้จ่ายเฉลี่ยต่อครัวเรือนเพิ่มขึ้น รวมถึงภาวะเศรษฐกิจที่กำลังผันผวนในปัจจุบัน ทางกลุ่มของเราได้เสนอสมมติฐานว่า ประชากรชาวไทยน่าจะมีแนวโน้มที่จะเพิ่มการออมเพื่อลดความเสี่ยงในอนาคต อย่างไรก็ตาม การศึกษาข้อมูลในความเป็นจริงพบว่า แนวโน้มการออมเงินของประชากรชาวไทยไม่ได้เป็นไปงตามที่เราคาดหวัง</h4>

# %% [markdown]
# <div id="interest">
# <h2><span style="color:lightBLue;"><strong>Real Interest Rate</strong></span></h2>
# </div>

# %%
url = "https://github.com/Schwinnnnn/Data_schwin_year_3/raw/main/Bi/project2/statistic_id794618_real-interest-rates-in-thailand-2013-2022.xlsx"
df4 = pd.read_excel(url,skiprows=4)
df4
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2 Unnamed: 3
# 0         NaN        2013        3.22       in %
# 1         NaN        2014        3.46       in %
# 2         NaN        2015        3.98       in %
# 3         NaN        2016        1.79       in %
# 4         NaN        2017        2.47       in %
# 5         NaN        2018        2.68       in %
# 6         NaN        2019        3.04       in %
# 7         NaN        2020        4.63       in %
# 8         NaN        2021        1.33       in %
# 9         NaN        2022       -1.51       in %

# %%
df4 = df4.drop(df4.columns[[0, 3]], axis=1)
df4 = df4.rename(columns={"Unnamed: 1": "Year", "Unnamed: 2": "Real interest rates(%)"})
df4
# Out:
#    Year  Real interest rates(%)
# 0  2013                    3.22
# 1  2014                    3.46
# 2  2015                    3.98
# 3  2016                    1.79
# 4  2017                    2.47
# 5  2018                    2.68
# 6  2019                    3.04
# 7  2020                    4.63
# 8  2021                    1.33
# 9  2022                   -1.51

# %%
sns.set_style("whitegrid")

sns.lineplot(data=df4, x='Year', y='Real interest rates(%)', marker='o', color='blue')

plt.axhline(y=0, color='black', linestyle='-', linewidth=2)

plt.title('')
plt.xlabel('Year')
plt.ylabel('Real interest rates')
plt.tight_layout()
plt.show()

# %% [markdown]
# <h4> ข้อมูลที่นำมาใช้ในการวิเคราะห์คือ อัตราดอกเบี้ยที่แท้จริงในช่วงปี 2013 ถึง 2022<br /><br />
# เพื่อศึกษาแนวโน้มของดอกเบี้ยที่แท้จริงและตลาดการเงิน จากกราฟทำให้เห็นได้ว่า
# <ul>
#       <li>ในช่วงปี 2013-2015: อัตราดอกเบี้ยจริงมีแนวโน้มเพิ่มสูงขึ้นเรื่อย ๆ </li>
#       <li>ในช่วงปี 2016-2018: อัตราดอกเบี้ยจริงมีแนวโน้มลดลงเล็กน้อย</li>
#       <li>ในช่วงปี 2019-2020: อัตราดอกเบี้ยจริงเพิ่มขึ้นอย่างมีนัยสำคัญ โดยเฉพาะในปี 2020 ที่มีการเพิ่มขึ้นอย่างสูง </li>
#       <li>ในช่วงปี 2021-2022: อัตราดอกเบี้ยจริงมีแนวโน้มลดลงอย่างมีนัยสำคัญโดยเฉพาะในปี 2022 ที่มีค่าติดลบ</li>
# </ul>
# จากกราฟนี้ทำให้ทราบถึงความผันผวนของอัตราดอกเบี้ยที่แท้จริงสำหรับการออมเงินและเศรษฐกิจ</h4>

# %% [markdown]
# <div id="save_invest">
# <h2><span style="color:lightBLue;"><strong>Saving and Investment</strong></span></h2>
# </div>

# %%
url = "https://raw.githubusercontent.com/Schwinnnnn/Data_schwin_year_3/main/Bi/project2/trends%20of%20searching%20on%20ggtrend.csv"
df5 = pd.read_csv(url,index_col='Week', parse_dates=True)
df5
# Out:
#             ออมเงิน: (Thailand)  ลงทุน: (Thailand)
# Week
# 2019-02-17                    4                 13
# 2019-02-24                    4                 12
# 2019-03-03                    4                 14
# 2019-03-10                    3                 13
# 2019-03-17                    3                 13
# ...                         ...                ...
# 2024-01-14                    4                 27
# 2024-01-21                    4                 27
# 2024-01-28                    5                 23
# 2024-02-04                    4                 22
# 2024-02-11                    4                 22
#
# [261 rows x 2 columns]

# %%
df5 = df5.rename_axis('Year')
df5.rename(columns={'ออมเงิน: (Thailand)': 'Searching for savings in Thailand'}, inplace=True)
df5.rename(columns={'ลงทุน: (Thailand)': 'Searching for investment in Thailand'}, inplace=True)
df5
# Out:
#             Searching for savings in Thailand  \
# Year
# 2019-02-17                                  4
# 2019-02-24                                  4
# 2019-03-03                                  4
# 2019-03-10                                  3
# 2019-03-17                                  3
# ...                                       ...
# 2024-01-14                                  4
# 2024-01-21                                  4
# 2024-01-28                                  5
# 2024-02-04                                  4
# 2024-02-11                                  4
#
#             Searching for investment in Thailand
# Year
# 2019-02-17                                    13
# 2019-02-24                                    12
# 2019-03-03                                    14
# 2019-03-10                                    13
# 2019-03-17                                    13
# ...                                          ...
# 2024-01-14                                    27
# 2024-01-21                                    27
# 2024-01-28                                    23
# 2024-02-04                                    22
# 2024-02-11                                    22
#
# [261 rows x 2 columns]

# %%
df5.plot()
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# <h4> ข้อมูลที่นำใช้ในการวิเคราะห์คือ แนวโน้มในการเปรียบเทียบความสนใจในการออมและการลงทุนของบุคคลไทยในช่วงระหว่างปี 2017-2024<br /><br />
# โดยกราฟอัตราดอกเบี้ยจริงอาจมีการเปลี่ยนแปลงและผันผวนตามที่ได้กล่าวไว้ข้างต้น แต่ก็ไม่ส่งผลต่อแนวโน้มการออมเงินของคนไทย จากกราฟทำใหทราบว่าความสนใจในการออมมีความคงที่อยู่เสมอไม่ว่าสถานการณ์เศรษฐกิจหรืออัตราดอกเบี้ยจะเปลี่ยนแปลงและมีการผันผวน แต่ในทางกลับกัน มีแนวโน้มที่ชัดเจนว่าคนไทยทมีความสนใจในการลงทุนเพิ่มขึ้นในช่วงเวลานี้ ซึ่งสังเกตได้จากกราฟ</h4>

# %% [markdown]
# <div id="summary">
# <h2><span style="color:lightBLue;"><strong>Summary</strong></span></h2>
# </div>
# <img src ="https://t1.blockdit.com/photos/2021/05/609ac0d272d8cf0c3e60f891_800x0xcover_lXfnI0re.jpg" height="240" >
# <img src="https://i.ibb.co/5G9m6yd/305194683-6017968144957914-2331919630294763959-n.jpg" height="240" >
# <h4>จากข้อมูลที่ได้กล่าวถึงข้างต้น แสดงให้เห็นว่าในปัจจุบัน คนไทยมีแนวโน้มที่จะเผชิญกับความท้าทายของค่าใช้จ่ายที่เพิ่มขึ้นอย่างมีนัยสำคัญ <br /><br />เนื่องจากรายได้ไม่เพียงพอกับค่าใช้จ่ายที่เพิ่มมากขึ้นเป็นจำนวนมาก อย่างไรก็ตามคนไทยส่วนใหญ่ยังมีแนวโน้มที่จะสนใจในการลงทุน ถึงแม้ว่าการลงทุนอาจเสี่ยงต่อความเสียหายมากกว่าการออมเงิน ดังนั้น สรุปได้ว่า <a href="https://www.longtunman.com/34940" target="_blank">เหตุผลที่คนไทยเลือกที่จะลงทุนมากกว่าการออมเงิน</a>มีดังต่อไปนี้
# <ol>
#       <li>การลงทุนในบริษัทนี้มีโอกาสที่จะให้ผลตอบแทนที่เป็นสมเหตุสมผลในระยะยาว และยังมีระดับความเสี่ยงที่ยอมรับได้ เนื่องจากมีพื้นฐานทางธุรกิจที่แข็งแกร่ง และมีการดำเนินงานจริงจังอย่างมีเสถียรภาพ หากธุรกิจขยายตัวและมีรายได้เพิ่มขึ้น ราคาหุ้นก็มีโอกาสปรับตัวขึ้นตามได้</li>
#       <li>หากเปรียบเทียบถึงผลตอบแทนนั้น การออมเงินมีผลตอบแทนอยู่ที่ 0.1%-4.4%  แต่การลงทุนนั้นมีผลตอบแทนที่มากถึง 4.0%-23.6%</li>
# </ol>
# </h4>
